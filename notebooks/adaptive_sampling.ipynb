# %%
import os
os.chdir('/home/sebastiaan/PhD/Repositories/immune_response_detection/')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from raptcr.hashing import Cdr3Hasher
from raptcr.indexing import IvfIndex
from raptcr.constants.datasets import sample_cdr3s, example

from multiprocessing import Pool
from timeit import default_timer as timer

# %% [markdown]
# ## Configure the search parameters

# %%
hasher = Cdr3Hasher(m=256).fit()

# def search_radius(seq, index:IvfIndex=index):
#     return len()

# %% [markdown]
# ### Foreground

# %%
# index = IvfIndex(hasher=hasher, n_centroids=1000, n_probe=10)

# starttime = timer()
# index.add(example)
# print(f'Time elapsed BUILDING the index: {np.round(timer()-starttime, 2)} seconds')

# starttime = timer()
# foreground = {seq:index.radius_search(seq, r=0.1, exclude_self=True) for seq in example}
# print(f'Time elapsed SEARCHING the index: {np.round(timer()-starttime, 2)} seconds (NO MULTIPROCESSING)')

# pool = Pool(processes=12)

# starttime = timer()
# counts = pool.map(search_radius, example)
foreground = find_neighbors_within_radius(
        query=example,
        dataset=example
        )

seq_with_nbrs = {i:foreground[i] for i in foreground if foreground[i] > 0}

# seq_with_nbrs = {i:len(foreground[i]) for i in foreground if len(foreground[i]) > 0}
# Out:
# Time elapsed BUILDING the index: 3.88 seconds
# Time elapsed SEARCHING the index: 25.36 seconds (WITH MULTIPROCESSING)

# %%
bg_counts = {i:[] for i in seq_with_nbrs}
bg_counts
# Out:
# {'CASSLSGAGNTIYF': [],
#  'CASSLLAGPYNEQFF': [],
#  'CASSTTGGYEQYF': [],
#  'CASSLLNLGTDTQYF': [],
#  'CASSLGGGTDTQYF': [],
#  'CASSLGLAGNEQFF': [],
#  'CASSLGAGGETQYF': [],
#  'CASSYVGGGNQPQHF': [],
#  'CASSLMDLNTGELFF': [],
#  'CASSRDRNYGYTF': [],
#  'CASSRTGGTNTEAFF': [],
#  'CASSRAGFYGYTF': [],
#  'CASSFGGAEQFF': [],
#  'CASSLEGIGNQPQHF': [],
#  'CASTSANTDTQYF': [],
#  'CASSLTAEQFF': [],
#  'CASSLSAEQFF': [],
#  'CASSLIPKGLNTGELFF': [],
#  'CASSRDRVSYEQYF': [],
#  'CASSFGGSSYEQYF': [],
#  'CASSFDSYSNQPQHF': [],
#  'CASSSRRGSTDTQYF': [],
#  'CASSSSATISYNEQFF': [],
#  'CASSLAGTLEKLFF': [],
#  'CASSTLGSTNEKLFF': [],
#  'CASSFPGTEAFF': [],
#  'CASSLGGGNTIYF': [],
#  'CASSLRTGATGELFF': [],
#  'CASSLGSGSYEQYF': [],
#  'CASSLRLGDTGELFF': [],
#  'CASSLAAGGPEAFF': [],
#  'CASSLVAGGSNTGELFF': [],
#  'CASSLLADTSTDTQYF': [],
#  'CASRSGANQETQYF': [],
#  'CASWTSGDEQFF': [],
#  'CASSLGGISDTQYF': [],
#  'CASSGGQGSNQPQHF': [],
#  'CASSLAQGRNYGYTF': [],
#  'CASSLGGANTQYF': [],
#  'CASSAPQGAYEQYF': [],
#  'CASSFSQGARTYEQYF': [],
#  'CASSLGVSHSYEQYF': [],
#  'CASSLRENTEAFF': [],
#  'CASSLEGRGETQYF': [],
#  'CASSLAGTGVYEQYF': [],
#  'CASSLGGGYGYTF': [],
#  'CASSLQGSPNYGYTF': [],
#  'CASSPTGTDTQYF': [],
#  'CASSLRPGQTYEQYF': [],
#  'CASSLAGSNQPQHF': [],
#  'CASSLQGEYYEQYF': [],
#  'CASSLLAQGEQYF': [],
#  'CASSFPPYEQYF': [],
#  'CASSLTSPSGANVLTF': [],
#  'CASSHTSTDTQYF': [],
#  'CASSLATSGSRYEQYF': [],
#  'CASRTGVEQYF': [],
#  'CASSLTLNTEAFF': [],
#  'CASSRTGLTNEKLFF': [],
#  'CASSLADSSNQPQHF': [],
#  'CASSLVWANTEAFF': [],
#  'CASRKLAQETQYF': [],
#  'CASSLEGNSGNTIYF': [],
#  'CASSLVGTSSSYNEQFF': [],
#  'CASSLERGGNTEAFF': [],
#  'CASSLGVNEQFF': [],
#  'CASSLVAGKSYEQYF': [],
#  'CASSFMNTEAFF': [],
#  'CASSGLGRLLNEQFF': [],
#  'CASSKQGREQYF': [],
#  'CASSIGTATGELFF': [],
#  'CASSGTVNTEAFF': [],
#  'CASSLGPETQYF': [],
#  'CASSLRPLYEQYF': [],
#  'CASSLGPYNEQFF': [],
#  'CASSLGPGYNEQFF': [],
#  'CASSLSTNEKLFF': [],
#  'CASSTGTFYNEQFF': [],
#  'CASSLTAGSSYEQYF': [],
#  'CASRSGSGTYNEQFF': [],
#  'CASSFGTHSNQPQHF': [],
#  'CASSLEGIGTDTQYF': [],
#  'CASSEGQGRNTIYF': [],
#  'CASSPAYEQYF': [],
#  'CASSSRGSQETQYF': [],
#  'CASSLVADSYGYTF': [],
#  'CASSLGASGQPQHF': [],
#  'CASSLQPSSSYEQYF': [],
#  'CASSRQGALGYTF': [],
#  'CASSLGGNTIYF': [],
#  'CASSSRGSGNTIYF': [],
#  'CASSSGQMNTEAFF': [],
#  'CASSWGTVSYEQYF': [],
#  'CASSFSGTLYEQYF': [],
#  'CASSRQGEDYGYTF': [],
#  'CASSSGLREAFF': [],
#  'CASSLGASNQPQHF': [],
#  'CASSLATGLTYGYTF': [],
#  'CANSYRVQETQYF': [],
#  'CASSQSPGPYNEQFF': [],
#  'CASSLGPGSSYEQYF': [],
#  'CASSPRQGRGEQYF': [],
#  'CASSFRDPYEQYF': [],
#  'CASSLILDAEAFF': [],
#  'CASSLSREGPYEQYF': [],
#  'CASSLGGQPQHF': [],
#  'CASSFLFQETQYF': [],
#  'CASSLDGSGELFF': [],
#  'CASSHRRGSEKLFF': [],
#  'CASSLQGGGDTQYF': [],
#  'CASSQDRGTYNEQFF': [],
#  'CASSLEGGAYNEQFF': [],
#  'CASSLERYSYNEQFF': [],
#  'CASSLSDYNEQFF': [],
#  'CASSTGHSSYEQYF': [],
#  'CASSLAHNEQFF': [],
#  'CASSSQGGSSYNEQFF': [],
#  'CASTLAVNTGELFF': [],
#  'CASSLGQYEQYF': [],
#  'CASSWGGGLEQYF': [],
#  'CASKASSYNEQFF': [],
#  'CASSLEGSDYGYTF': [],
#  'CASSSVYGYTF': [],
#  'CASSQNEQYF': [],
#  'CASSRNNEQFF': [],
#  'CASSLGTAPMNTEAFF': [],
#  'CASSPPGELFF': [],
#  'CASSPGLAGVNEQFF': [],
#  'CASSLVSYEQYF': [],
#  'CASSPGGMNTEAFF': [],
#  'CASSPGQGGQPQHF': [],
#  'CASSSIQGGTDTQYF': [],
#  'CASSPRDGKLFF': [],
#  'CASSPGRKNTEAFF': [],
#  'CASSPVMDTQYF': [],
#  'CASSLDFLYEQYF': [],
#  'CASSLASVAEQYF': [],
#  'CASSPGGTQYF': [],
#  'CASSLVGNTEAFF': [],
#  'CASSLAAGLFQETQYF': [],
#  'CASSLEGASTDTQYF': [],
#  'CASSPTGGKTEAFF': [],
#  'CASSPATEAFF': [],
#  'CASSLGLAETDTQYF': [],
#  'CASSPRTANTGELFF': [],
#  'CASSPRGNTGELFF': [],
#  'CASSPGQGMNGYTF': [],
#  'CASSLAGSTEAFF': [],
#  'CASSSAGESSTDTQYF': [],
#  'CASSLGVDEQFF': [],
#  'CASSLAGTGVTDTQYF': [],
#  'CASSPPVIETQYF': [],
#  'CASSPRTSGRNNEQFF': [],
#  'CASSPLGQGSSYEQYF': [],
#  'CASSRTSGLYEQYF': [],
#  'CASSPLRGGETQYF': [],
#  'CASSPPGQGYNEQFF': [],
#  'CASSLTQETQYF': [],
#  'CASSHGQGGNQPQHF': [],
#  'CASRPGTSGSTDTQYF': [],
#  'CASSLWSYNEQFF': [],
#  'CASSPGTRYNEQFF': [],
#  'CASSILPQGSSYNEQFF': [],
#  'CASSSALYEQYF': [],
#  'CASSPPRGLDTQYF': [],
#  'CASSPDRSYEQYF': [],
#  'CASSPDRLGYEQYF': [],
#  'CASSPASTNEKLFF': [],
#  'CASSPFRGYEQYF': [],
#  'CASSQPTGGYEQYF': [],
#  'CASSLTSGRVGEQYF': [],
#  'CASSFDDDGYTF': [],
#  'CASSRGIMNTEAFF': [],
#  'CASSLVVATNEKLFF': [],
#  'CASTDKGNEQFF': [],
#  'CASSLGGYDTDTQYF': [],
#  'CASSSGPVEQYF': [],
#  'CASSSDRVYGYTF': [],
#  'CASSFQGVSNQPQHF': [],
#  'CASSLEPGVQPQHF': [],
#  'CASSPIGGDEQYF': [],
#  'CASSLEARNTEAFF': [],
#  'CASSPGQGAYTGELFF': [],
#  'CASSPIGQGLGEQYF': [],
#  'CASSPEGEAFF': [],
#  'CASSPGTGRTEAFF': [],
#  'CASSPIAGLTTGELFF': [],
#  'CASSQSEETQYF': [],
#  'CASSRGYEQYF': [],
#  'CASSLGGLGTDTQYF': [],
#  'CASSLSGSGVWNEQFF': [],
#  'CASLTSGKTDTQYF': [],
#  'CASSLRTGNQPQHF': [],
#  'CASGTSGSHEQYF': [],
#  'CASSPVQETQYF': [],
#  'CASSPGRTNTGELFF': [],
#  'CASSSRRETGELFF': [],
#  'CASSLSRTYEQYF': [],
#  'CASSASGSKNQPQHF': [],
#  'CASSLTDLTYEQYF': [],
#  'CASSLGILAGRSYEQYF': [],
#  'CASSLEETQYF': [],
#  'CASRRSGSNYGYTF': [],
#  'CASSFTGNEQFF': [],
#  'CASSLAQVSYNEQFF': [],
#  'CASSPVTSTDTQYF': [],
#  'CASSPNREKLFF': [],
#  'CASSPFVAPYNEQFF': [],
#  'CASSPLDTNSGNTIYF': [],
#  'CASSLSDGNTEAFF': [],
#  'CASSLGRRTETQYF': [],
#  'CASSLGPTSNQPQHF': [],
#  'CASSFRQTYNEQFF': [],
#  'CASSRLAGNNEQFF': [],
#  'CASSPISGGNTEAFF': [],
#  'CASSPLVGELFF': [],
#  'CASSQKGTGANVLTF': [],
#  'CASTGVAEQFF': [],
#  'CASSLDRAVYGYTF': [],
#  'CASSQTSGIVNEQFF': [],
#  'CASSYRTGGSGYEQYF': [],
#  'CASSLGDRANQPQHF': [],
#  'CASSLGRVNQPQHF': [],
#  'CASSFTANTEAFF': [],
#  'CASSPLAVFSYNEQFF': [],
#  'CASSPRGRTSTDTQYF': [],
#  'CASSLGLAGGETQYF': [],
#  'CASSPDRGGNEQFF': [],
#  'CASSLVEGLGEQYF': [],
#  'CASSLVGGMGTGELFF': [],
#  'CASSLGAGPYEQYF': [],
#  'CASSPSRGRTGELFF': [],
#  'CASSPGRGETQYF': [],
#  'CASSSRGQGTDTQYF': [],
#  'CASSPRLAGGYEQFF': [],
#  'CASSPGPGANVLTF': [],
#  'CASSPKRTTDTQYF': [],
#  'CASSRDSINTEAFF': [],
#  'CASSLAVFYEQYF': [],
#  'CASSSQTGLNTEAFF': [],
#  'CASSTDRNTEAFF': [],
#  'CASSIPGGGEQYF': [],
#  'CASSLYGYEQYF': [],
#  'CASSQGASGQETQYF': [],
#  'CASSPLRSSYEQYF': [],
#  'CASSPALRDTEAFF': [],
#  'CASSSLGSPSYNEQFF': [],
#  'CASSLLVQETQYF': [],
#  'CASSLGLAVSTDTQYF': [],
#  'CASSLTAYTGELFF': [],
#  'CASSSQPTDTQYF': [],
#  'CASSPGGSYNEQFF': [],
#  'CASSQWDRGNEQFF': [],
#  'CASTPQTGGNTEAFF': [],
#  'CASSWGSYEQYF': [],
#  'CASSLWDRETDTQYF': [],
#  'CASSRLAGGINEQFF': [],
#  'CASNLEGARSYEQYF': [],
#  'CASSLGVPAYEQYF': [],
#  'CASSLGAGASYEQYF': [],
#  'CASSYTDTQYF': [],
#  'CASSLGVQAEAFF': [],
#  'CASSLSTYEQYF': [],
#  'CASSRSGGGYTF': [],
#  'CASSPPGPQRYF': [],
#  'CASSRDLGETQYF': [],
#  'CASSPQGYEQYF': [],
#  'CASSLNRAQETQYF': [],
#  'CASSPPVGGSGNTIYF': [],
#  'CASSLAAGQNTEAFF': [],
#  'CASSLERENTEAFF': [],
#  'CASSLFKNTEAFF': [],
#  'CASSLTGQGAEAFF': [],
#  'CASSLGRLNTEAFF': [],
#  'CASSFGTTGELFF': [],
#  'CASSLGTGGSGANVLTF': [],
#  'CASSLAQGPYEQYF': [],
#  'CASSLVGGYTF': [],
#  'CASSLRQDNEQFF': [],
#  'CASSPDSSSYNEQFF': [],
#  'CASSRLAGRYNEQFF': [],
#  'CASSLMSSGSSYNEQFF': [],
#  'CASSLSGRGTDTQYF': [],
#  'CASSLGPNTGELFF': [],
#  'CASSPVAGGHNEQFF': [],
#  'CASSPLDTGELFF': [],
#  'CASSLYGGSQPQHF': [],
#  'CASSLAGGGRQPQHF': [],
#  'CASTRADTQYF': [],
#  'CASSSDTYSYEQYF': [],
#  'CASSLLGTGANVLTF': [],
#  'CASSLASGSVGEQFF': [],
#  'CASSLEGTGANVLTF': [],
#  'CASSEGRGRGTDTQYF': [],
#  'CASSLSEGSYNEQFF': [],
#  'CASQDTSSYNEQFF': [],
#  'CASSPNRGRGYNEQFF': [],
#  'CASSLRLREGYTF': [],
#  'CASKDRGAGELFF': [],
#  'CASSAVDTGELFF': [],
#  'CASSLGTGRSSYEQYF': [],
#  'CASSLATGGDYGYTF': [],
#  'CASSIVSTTNEKLFF': [],
#  'CASSLAGGYEQYF': [],
#  'CASSFSDGVSYEQYF': [],
#  'CASSLGVYEQYF': [],
#  'CASSGTLVGPPYEQYF': [],
#  'CASSEGAGNTIYF': [],
#  'CASSLSIIGNQPQHF': [],
#  'CASSLQSSGANVLTF': [],
#  'CASSPQTAGNTIYF': [],
#  'CASSPLATSTDTQYF': [],
#  'CASSPRTGNTGELFF': [],
#  'CASSPEETQYF': [],
#  'CASSLEGARGNQPQHF': [],
#  'CASSPVTGGITEAFF': [],
#  'CASSLGGGTEAFF': [],
#  'CASSQTGTVETQYF': [],
#  'CASSLAGRQPQHF': [],
#  'CASSLVPVGNEQFF': [],
#  'CASSLVTDTQYF': [],
#  'CASSLKGPGYGYTF': [],
#  'CASSLRGVTDTQYF': [],
#  'CASSFTRASTDTQYF': [],
#  'CASSEDRAADTQYF': [],
#  'CASSEIGLAGQETQYF': [],
#  'CASSLGTANTGELFF': [],
#  'CASGAGYTGELFF': [],
#  'CASSELTGNIQYF': [],
#  'CASSPGSEQYF': [],
#  'CASSLSSGQTYEQYF': [],
#  'CASSLGPQPQHF': [],
#  'CASSPTDRDQPQHF': [],
#  'CASSPVTSGTGELFF': [],
#  'CASSLPLAGGNEQFF': [],
#  'CASSPQQGPDTGELFF': [],
#  'CASSPRGVYNEQFF': [],
#  'CASSVELYNEQFF': [],
#  'CASSPRRNEQFF': [],
#  'CASSPRGLSNQPQHF': [],
#  'CASSKTGGGNQPQHF': [],
#  'CASEGGGTYEQYF': [],
#  'CASTEGVGNEQFF': [],
#  'CASSLELGEQFF': [],
#  'CASSLRLDQETQYF': [],
#  'CASSLGGINTGELFF': [],
#  'CASSTGTGGLLETQYF': [],
#  'CASSLAGQYNEQFF': [],
#  'CASSLGTGYSTDTQYF': [],
#  'CASSLSGGNGYTF': [],
#  'CASGLGPAYEQYF': [],
#  'CASSDGGASTDTQYF': [],
#  'CASERGPGELFF': [],
#  'CASRPTSGSYEQYF': [],
#  'CASSLSDSSGNTIYF': [],
#  'CASSLGQGPYEQYF': [],
#  'CASSYPPNEKLFF': [],
#  'CASSSPGQGFNEQFF': [],
#  'CASSLALGANTEAFF': [],
#  'CASSRGQGRYEQYF': [],
#  'CASSFGENTEAFF': [],
#  'CASSLEGLGNQPQHF': [],
#  'CASSPRPEETQYF': [],
#  'CASSLFGETQYF': [],
#  'CASSPRDRVNEQFF': [],
#  'CASSPGLAEGETQYF': [],
#  'CASSQPMRYEQYF': [],
#  'CASGLGQGADTQYF': [],
#  'CASAVAGGPEQFF': [],
#  'CASGLGSYNEQFF': [],
#  'CASRKNRGSTGELFF': [],
#  'CASSKGQGDEKLFF': [],
#  'CASSETRQGSTEAFF': [],
#  'CASSGGTSGYNEQFF': [],
#  'CASSDLGQETQYF': [],
#  'CASSEAGVGNTIYF': [],
#  'CASSLSGGNNEQFF': [],
#  'CASSLLPRQGRTYNEQFF': [],
#  'CASSLSGRPTDTQYF': [],
#  'CASLSENYEQYF': [],
#  'CASSLSPDRVETQYF': [],
#  'CASSLVSSGNTIYF': [],
#  'CASSVLAGDYEQYF': [],
#  'CASSVGTAAYEQYF': [],
#  'CASSEALGVNYGYTF': [],
#  'CASSSDGSGQPQHF': [],
#  'CASSREVAYEQYF': [],
#  'CASREGISNQPQHF': [],
#  'CASARDLNTEAFF': [],
#  'CASSPTGTNYGYTF': [],
#  'CASSPGGLGYEQYF': [],
#  'CASSTQETQYF': [],
#  'CASSLGLVSYNEQFF': [],
#  'CASSLGQGQPQHF': [],
#  'CASSPRGGTSYNEQFF': [],
#  'CASSLIGGTGGTGELFF': [],
#  'CASGLDYQPQHF': [],
#  'CASGLRGDEQFF': [],
#  'CASSLASGEAFF': [],
#  'CASRILASTDTQYF': [],
#  'CASSSLSTQETQYF': [],
#  'CASSFGDRTDTQYF': [],
#  'CASSLSDSPYEQYF': [],
#  'CASSLDPNEKLFF': [],
#  'CASSPDGPYGYTF': [],
#  'CASSPSGSSSGANVLTF': [],
#  'CASSERGGGNEQFF': [],
#  'CASSAGVANQPQHF': [],
#  'CASSGGENYGYTF': [],
#  'CASSLGTGAYEQYF': [],
#  'CASSLSTVNTEAFF': [],
#  'CASSLWGGQPQHF': [],
#  'CASSFMANTGELFF': [],
#  'CASRLTGDEQFF': [],
#  'CASRGGETQYF': [],
#  'CASSRQGADTDTQYF': [],
#  'CASSPPGLLNEQFF': [],
#  'CASSDRGGDQPQHF': [],
#  'CASSPPGGGYEQYF': [],
#  'CASSSGLGSDTQYF': [],
#  'CASSLDLALGTDTQYF': [],
#  'CASSMSGSTGELFF': [],
#  'CASGLGAGTGYGYTF': [],
#  'CASTGMNTEAFF': [],
#  'CASGGDRGNTEAFF': [],
#  'CASGLTGDEQFF': [],
#  'CASSLQGRDTGELFF': [],
#  'CASSQSESDEQYF': [],
#  'CASSIGTSLNEQFF': [],
#  'CASSLGLTAYEQYF': [],
#  'CASSLNEKLFF': [],
#  'CASSVTGMINTGELFF': [],
#  'CASSQINEKLFF': [],
#  'CATRWGDEQFF': [],
#  'CASSVLQMNTEAFF': [],
#  'CASSGGSRETQYF': [],
#  'CASSLAAGKEQYF': [],
#  'CASSTGGDNQPQHF': [],
#  'CASSRTSDEQFF': [],
#  'CASSPPSQGETQYF': [],
#  'CASSSILAGGEQFF': [],
#  'CASSLTGTGNYNEQFF': [],
#  'CASSLWGGSSYNEQFF': [],
#  'CASGQGGNTEAFF': [],
#  'CASSQGANTEAFF': [],
#  'CASSLVGTLNQPQHF': [],
#  'CASSLTGTGPYEQYF': [],
#  'CASSFGDYYEQYF': [],
#  'CASSLGRTYEQYF': [],
#  'CASSEWRTEAFF': [],
#  'CASSGRVSEAFF': [],
#  'CASKGKQEAFF': [],
#  'CASREMNTEAFF': [],
#  'CASSPPGRDEQYF': [],
#  'CASSPKPGGGADTQYF': [],
#  'CASSPSVGGGYTF': [],
#  'CASSPLSMNTEAFF': [],
#  'CASSPGNSYGYTF': [],
#  'CASSSPGRNEQFF': [],
#  'CASSLGAGNEQFF': [],
#  'CASSLTGSGNTIYF': [],
#  'CASSLNRGDTDTQYF': [],
#  'CASSLEVNYGYTF': [],
#  'CASSLTGVNTEAFF': [],
#  'CASSLRGGLTDTQYF': [],
#  'CASSLEGGSGETQYF': [],
#  'CASSLEREGTYEQYF': [],
#  'CASSLGQISNQPQHF': [],
#  'CASSSRTGYTEAFF': [],
#  'CASSLEGQGSQPQHF': [],
#  'CASSLTENTEAFF': [],
#  'CASSLQGMNTEAFF': [],
#  'CASSRGAYNEQFF': [],
#  'CASSRVVQETQYF': [],
#  'CASSLGQGYEQYF': [],
#  'CASSLLTGNNQPQHF': [],
#  'CASSLGQLNTEAFF': [],
#  'CASSLEVSGGSYEQYF': [],
#  'CASSQEETQYF': [],
#  'CASSLQGDSNQPQHF': [],
#  'CASSLKGDRNTEAFF': [],
#  'CASSLAGETQYF': [],
#  'CASSNLPDTQYF': [],
#  'CASGLGSIQETQYF': [],
#  'CASGRDYYEQYF': [],
#  'CASSQGTSGYNEQFF': [],
#  'CASSATGGGEQFF': [],
#  'CASSLRGAGNIQYF': [],
#  'CASSTRTDNEQFF': [],
#  'CASSQGRGNTEAFF': [],
#  'CASRGGRSSYNEQFF': [],
#  'CASSGGSANTGELFF': [],
#  'CASRDRGRNEQFF': [],
#  'CASSDLLLQPQHF': [],
#  'CASIGGRAADTQYF': [],
#  'CASEGHGNQPQHF': [],
#  'CASSPSSYEQYF': [],
#  'CASSPGTGGQPQHF': [],
#  'CASSRASGVYEQYF': [],
#  'CASSALSGSGNTIYF': [],
#  'CASSPRRSYEQYF': [],
#  'CASSPGGGGGYEQYF': [],
#  'CASSPNRASYEQYF': [],
#  'CASSLWGMNQPQHF': [],
#  'CASSFLGSEQFF': [],
#  'CASSPTGGNSNQPQHF': [],
#  'CASSWGQENQPQHF': [],
#  'CASSLGALGTNEKLFF': [],
#  'CASTQRQGATNTEAFF': [],
#  'CASSPLGQGNTEAFF': [],
#  'CASGLNKNTEAFF': [],
#  'CASSPQGRNTGELFF': [],
#  'CASSLGHSTDTQYF': [],
#  'CASSGGQGSYNEQFF': [],
#  'CASSLTGYEQYF': [],
#  'CASSFSDGSYEQYF': [],
#  'CASSAVVGTYEQYF': [],
#  'CASSLHSLTYEQYF': [],
#  'CASGRDLNQPQHF': [],
#  'CASAQGYNQPQHF': [],
#  'CASALGGGTEAFF': [],
#  'CASSGGTGEYGYTF': [],
#  'CASSLSGPVGNTIYF': [],
#  'CASSFLRASYNEQFF': [],
#  'CASSPTGSTEAFF': [],
#  'CASSLVSNEQFF': [],
#  'CASSLGLAATDTQYF': [],
#  'CASGQGPYNEQFF': [],
#  'CASRKGPNYGYTF': [],
#  'CASAPMNTGELFF': [],
#  'CASGLSGAADTQYF': [],
#  'CASRTGGYNEQFF': [],
#  'CANSDNYNWPYEQYF': [],
#  'CASSGGRPDTQYF': [],
#  'CASSDRAGGPTEQFF': [],
#  'CASSSMGRGSGANVLTF': [],
#  'CASSAEYEQYF': [],
#  'CASSLEGRGNEKLFF': [],
#  'CASSPGANTGELFF': [],
#  'CASSLGGTDTQYF': [],
#  'CASSLREEQFF': [],
#  'CASSSTLETQYF': [],
#  'CASSSGHQYF': [],
#  'CASSPTGVRNEKLFF': [],
#  'CASREGNTGELFF': [],
#  'CASSLGQGPYYEQYF': [],
#  'CASSPTGGGYEQYF': [],
#  'CASSLVSSSEAFF': [],
#  'CASSQQDQETQYF': [],
#  'CASSPRQGAAQETQYF': [],
#  'CASSPSSAEAFF': [],
#  'CASSQKGGGYEQYF': [],
#  'CASAGDTEAFF': [],
#  'CASAHTGELFF': [],
#  'CASSLSGGTDTQYF': [],
#  'CASSYSSAGTSYEQYF': [],
#  'CASSFAGSYEQYF': [],
#  'CASSPVGSLEQYF': [],
#  'CASSLDATTDTQYF': [],
#  'CASMRTGSYEQYF': [],
#  'CASSAGQSTDTQYF': [],
#  'CASSDGAKNIQYF': [],
#  'CASSETAGANVLTF': [],
#  'CASSLGGQKETQYF': [],
#  'CASGVTDTQYF': [],
#  'CASASQSNQPQHF': [],
#  'CASSLAGGTRDEQFF': [],
#  'CASSSGLAGGYEQFF': [],
#  'CASSSSGSYEQYF': [],
#  'CASSFLAGVAGELFF': [],
#  'CASSLEGTGGEKLFF': [],
#  'CASSWESATNEKLFF': [],
#  'CASSLRGSGYNEQFF': [],
#  'CASSFRDRGQPQHF': [],
#  'CAGGIQETQYF': [],
#  'CASSPRDTQPQHF': [],
#  'CASSPPGGEDEQYF': [],
#  'CASSPLPTADTQYF': [],
#  'CASSLVGDEKLFF': [],
#  'CASSPLGTSPSYEQYF': [],
#  'CASSDKGSYEQYF': [],
#  'CASSLFQNTEAFF': [],
#  'CASGLEGNTEAFF': [],
#  'CASSLGSGSYNEQFF': [],
#  'CASSSTGPNQPQHF': [],
#  'CASSARVDYGYTF': [],
#  'CASSQRTGTYEQYF': [],
#  'CASSFLGGGNEQFF': [],
#  'CASSPAGGTGELFF': [],
#  'CASSLLESNEQFF': [],
#  'CASSPLGGGRTYNEQFF': [],
#  'CASSLVENTGELFF': [],
#  'CASSPLSEGYEQYF': [],
#  'CASSPLSGGTDTQYF': [],
#  'CASSPRSGLQETQYF': [],
#  'CASAVTGGGTEAFF': [],
#  'CASSPGQKNTEAFF': [],
#  'CASSFSGSSSYNEQFF': [],
#  'CASSLSWANEKLFF': [],
#  'CASTSGSQETQYF': [],
#  'CASTFGGLGYEQYF': [],
#  'CASSFGVHTEAFF': [],
#  'CASKIADTEAFF': [],
#  'CASTPSGINSPLHF': [],
#  'CASALRTGELFF': [],
#  'CASSENNEQFF': [],
#  'CASCPGFVGGYKQYF': [],
#  'CASSRLAGSTDTQYF': [],
#  'CASSFVTINEQFF': [],
#  'CASSLGGVRGYTF': [],
#  'CASSLGTSGKNEQYF': [],
#  'CASSPRQGPTEAFF': [],
#  'CASSPRQGMNTEAFF': [],
#  'CASSLTFSDTQYF': [],
#  'CASKGNEQFF': [],
#  'CASSPSSGSTEAFF': [],
#  'CASSPDRDGQPQHF': [],
#  'CASSQDEKLFF': [],
#  'CASSLLGQGNTEAFF': [],
#  'CASSPPGGSYNEQFF': [],
#  'CASSLGQGASTEAFF': [],
#  'CASSLGDTQYF': [],
#  'CASSLVLAGVRDTQYF': [],
#  'CASSLASTNTGELFF': [],
#  'CASSPGRTSTDTQYF': [],
#  'CASSLVIATTDTQYF': [],
#  'CASSLAGRATEAFF': [],
#  'CASSLASGPTDTQYF': [],
#  'CASSLGPSQETQYF': [],
#  'CASSLTGGDEKLFF': [],
#  'CASSEAGVSYNEQFF': [],
#  'CASRDSNTDTQYF': [],
#  'CASTGLAGNNEQFF': [],
#  'CASSVQGVTYEQYF': [],
#  'CASSLVGTSLNEQFF': [],
#  'CASGLVETQYF': [],
#  'CASGLAGGYGYTF': [],
#  'CASSLNGGELFF': [],
#  'CASSSGTSGPDTQYF': [],
#  'CASSELAGGRNEQFF': [],
#  'CASSLTGKNTEAFF': [],
#  'CASSITGGGNQPQHF': [],
#  'CASSLGSLAGEQYF': [],
#  'CASSLVSLGNEQFF': [],
#  'CASSLGGRQAYGYTF': [],
#  'CASSFTGDTEAFF': [],
#  'CASSINPYNEQFF': [],
#  'CASSITGSTDTQYF': [],
#  'CASSTPGGSGANVLTF': [],
#  'CASRSGGANTEAFF': [],
#  'CASSLGNTEAFF': [],
#  'CASSETGNYGYTF': [],
#  'CASSRLPSGREETQYF': [],
#  'CASSATGLSYNEQFF': [],
#  'CASSGTSGRNYNEQFF': [],
#  'CASKGGRSGANVLTF': [],
#  'CASSPGVVYEQYF': [],
#  'CASSPIGVANEKLFF': [],
#  'CASSPKRSSYEQYF': [],
#  'CASSPDRPTGELFF': [],
#  'CSARDLETQYF': [],
#  'CSARVRNEQFF': [],
#  'CSARLGNEQFF': [],
#  'CSRTRADTQYF': [],
#  'CSARLRNEQFF': [],
#  'CSASDSYEQYF': [],
#  'CSLAGVNEQYF': [],
#  'CSASLNTQYF': [],
#  'CASSLSMGLAGLEQFF': [],
#  'CASSLGLAGLGETQYF': [],
#  'CASSLLSGTYNEQFF': [],
#  'CASTPGGREVYGYTF': [],
#  'CASSLAGQVLYEQYF': [],
#  'CASSGTGGDTQYF': [],
#  'CASSSPGTGPYNEQFF': [],
#  'CASGLGSGNTEAFF': [],
#  'CASIPDRANTGELFF': [],
#  'CASSSPDTYEQYF': [],
#  'CASSPGFGDTQYF': [],
#  'CASSLTEGQPQHF': [],
#  'CASSLTSGSINEQFF': [],
#  'CASSLGGGGTDTQYF': [],
#  'CASSIGRANEQYF': [],
#  'CASSLDSYSNQPQHF': [],
#  'CASSPGPYNEQFF': [],
#  'CASRQEYEQYF': [],
#  'CASQGGTEAFF': [],
#  'CASKAGGELFF': [],
#  'CASRVAGRGTDTQYF': [],
#  'CASSPTGTEETQYF': [],
#  'CASSRLAGVTGELFF': [],
#  'CASSLAAMSYNEQFF': [],
#  'CASSPSGSHANEQFF': [],
#  'CASSLDSGAGELFF': [],
#  'CASSSTGTGLNEQFF': [],
#  'CASSPAGGNQPQHF': [],
#  'CASSLSAETQYF': [],
#  'CASSLGGSYNEQFF': [],
#  'CASSLGVRNTEAFF': [],
#  'CASGLNSYEQYF': [],
#  'CASGSSGGGNEQFF': [],
#  'CASSPGSDYEQYF': [],
#  'CASSPRSDEKLFF': [],
#  'CASSPGQARDEQYF': [],
#  'CASSQETGQETQYF': [],
#  'CASSSGLATGELFF': [],
#  'CASSFAGTSTDTQYF': [],
#  'CAHSPGTDTQYF': [],
#  'CASSFQQGGTDTQYF': [],
#  'CASREESYNEQFF': [],
#  'CASSQGGGWSNQPQHF': [],
#  'CSARYNEQFF': [],
#  'CSATSYEQYF': [],
#  'CSAKRATEAFF': [],
#  'CSASLVGEQYF': [],
#  'CSADRQETQYF': [],
#  'CASSLAVVGYNEQFF': [],
#  'CASSLLGSNEKLFF': [],
#  'CASSYTGLSSYEQYF': [],
#  'CASSLTGTGGEKLFF': [],
#  'CASSATGGNGYTF': [],
#  'CASSLVGNTYEQYF': [],
#  'CASSLGGLDEQFF': [],
#  'CASSLAGGVTEAFF': [],
#  'CASSLNRDTHEQYF': [],
#  'CASSPFGTDTQYF': [],
#  'CASGPSVDTQYF': [],
#  'CASGPGGGTEAFF': [],
#  'CASGGGTEAFF': [],
#  'CASSQLGLAGVGETQYF': [],
#  'CASSPQGSYNEQFF': [],
#  'CASSFGSGTSSYEQYF': [],
#  'CASSLGGGDGYTF': [],
#  'CASSIADTQYF': [],
#  'CASSLAGGQETQYF': [],
#  'CASSPRTGGVTYNEQFF': [],
#  'CASSIEGLAGNEQFF': [],
#  'CASSSLYEQFF': [],
#  'CASKTGAGANVLTF': [],
#  'CASSIRGNNQPQHF': [],
#  'CGTGTGNQPQHF': [],
#  'CASTREGRELFF': [],
#  'CASTGGPYEQYF': [],
#  'CASGSSGGSYNEQFF': [],
#  'CASSYGVSTDTQYF': [],
#  'CASSVGLAGAQYF': [],
#  'CASSLLGGASYNEQFF': [],
#  'CASRMTGVNEQFF': [],
#  'CASSPPSQETQYF': [],
#  'CASSPKSYSNQPQHF': [],
#  'CASSPGQAEAFF': [],
#  'CASYGRSGTDTQYF': [],
#  'CASSLAGMIKETQYF': [],
#  'CASSPLTGTQETQYF': [],
#  'CASSWGSLGEQFF': [],
#  'CASSPRTSGRSSYEQYF': [],
#  'CASSLDLVAEQYF': [],
#  'CASSLEASNQPQHF': [],
#  'CASSLSGGGLNTEAFF': [],
#  'CASSFVAGNGEQFF': [],
#  'CASSLEDNSNQPQHF': [],
#  'CASSLGHLETQYF': [],
#  'CASGLVPGGAEAFF': [],
#  'CASGLQYNEQFF': [],
#  'CASSPPPGLTYNEQFF': [],
#  'CASRLAGTDTQYF': [],
#  'CASSPEGRGADTQYF': [],
#  'CASSLGLDSYNEQFF': [],
#  'CASSRTTGTGLNEQFF': [],
#  'CASSLVLAGGREQYF': [],
#  'CASSVTGGAYNEQFF': [],
#  'CASSLGQNYGYTF': [],
#  'CASSSTGVGTDTQYF': [],
#  'CASSLGGGRTYNEQFF': [],
#  'CASSSLAGNNEQFF': [],
#  'CASSWGTGSDEQYF': [],
#  'CASRGILQETQYF': [],
#  'CASSGIRGYEQYF': [],
#  'CASSSSGLTGELFF': [],
#  'CASSFTSGRAGELFF': [],
#  'CASSRDSHYEQYF': [],
#  'CASSYDYEQYF': [],
#  'CASSLTGAQGEKLFF': [],
#  'CASSFDRGRFTGELFF': [],
#  'CSARSDGEAFF': [],
#  'CSARGTEQFF': [],
#  'CSVSLNTEAFF': [],
#  'CSAAAEETQYF': [],
#  'CSAAAYNEQFF': [],
#  'CSAGDSYEQYF': [],
#  'CASTRGSEQFF': [],
#  'CASSGGLLNEQFF': [],
#  'CASSPGYEQYF': [],
#  'CASSLQGVNYGYTF': [],
#  'CASSLVFGELFF': [],
#  'CASELAGHTDTQYF': [],
#  'CASSPPGPGNTIYF': [],
#  'CASSEGQGAFYEQYF': [],
#  'CASSFGRNTEAFF': [],
#  'CASSLKASYEQFF': [],
#  'CASSFDGYEQYF': [],
#  'CASRESYNEQFF': [],
#  'CASLAGYEQYF': [],
#  'CASSLRDGFYEQYF': [],
#  'CASSLITGSYNEQFF': [],
#  'CASSQFYEQYF': [],
#  'CASSLQGVGYTF': [],
#  'CASSLAFNEKLFF': [],
#  'CASSLGGLAGNTDTQYF': [],
#  'CASSLDQETQYF': [],
#  'CASTEHNEQFF': [],
#  'CASSQTGAYNEQFF': [],
#  'CASSPVGDETQYF': [],
#  'CASSRSGTGMETQYF': [],
#  'CASSPRQSKYSYEQYF': [],
#  'CASSLQGTEQYF': [],
#  'CASSPGTGTQYF': [],
#  'CASGAQGNTGELFF': [],
#  'CASGSGAGVTGELFF': [],
#  'CSAVRDTQYF': [],
#  'CSASSQETQYF': [],
#  'CSARDGEEFF': [],
#  'CSARVTTEQYF': [],
#  'CASSLGGNTEAFF': [],
#  'CASSSGGADTQYF': [],
#  'CASRSGWDTEAFF': [],
#  'CASSDRQNQPQHF': [],
#  'CASSGRERGGGTQYF': [],
#  'CASSGDSQGYTF': [],
#  'CASSEVAANTGELFF': [],
#  'CASSLQGDGNQPQHF': [],
#  'CASSLVTGVNTEAFF': [],
#  'CASSSGVEQYF': [],
#  'CASSLGEGSTYEQYF': [],
#  'CASSIGRTSSYEQYF': [],
#  'CASSMAGVFGYTF': [],
#  'CASSLGQGKDQPQHF': [],
#  'CASSDGVNEKLFF': [],
#  'CASSSRYTGELFF': [],
#  'CASSFRETQYF': [],
#  'CASSGDSSYEQYF': [],
#  'CASSPDRAFYEQYF': [],
#  'CASSFSSSYNEQFF': [],
#  'CASSQDTGELFF': [],
#  'CASSLVSYQETQYF': [],
#  'CASSLDRAEAFF': [],
#  'CASIFSNEQFF': [],
#  'CASSLLGGSSYEQYF': [],
#  'CASSDSTEAFF': [],
#  'CASSLPGANEQFF': [],
#  'CASSILQGNYGYTF': [],
#  'CASSFARGGNYGYTF': [],
#  'CASSLLGSNQPQHF': [],
#  'CASSLQGWNTEAFF': [],
#  'CASILGQGGQPQHF': [],
#  'CASSSGSASETQYF': [],
#  'CASSLQGVVSYEQYF': [],
#  'CASSGTQETQYF': [],
#  'CASSLGRDPTYEQYF': [],
#  'CASSPRQGDTGELFF': [],
#  'CASSLAGGSEQYF': [],
#  'CASSLDRNSNQPQHF': [],
#  'CASSPPLVDYGYTF': [],
#  'CASSPRTGYAEQYF': [],
#  'CASSLGGKGENTEAFF': [],
#  'CASVDSTGELFF': [],
#  'CASGQPSGANVLTF': [],
#  'CSATPSNEQFF': [],
#  'CSANRGNEQFF': [],
#  'CSAQTSGEQYF': [],
#  'CSASIYGYTF': [],
#  'CSARDQREQYF': [],
#  'CSARAIGEQYF': [],
#  'CSARPGDEQFF': [],
#  'CSARKEDTQYF': [],
#  'CSAAGYEQYF': [],
#  'CASSEDRGRNEKLFF': [],
#  'CASSPRDRNEKLFF': [],
#  'CASSFGPSYEQYF': [],
#  'CASSLAGTSGSSYNEQFF': [],
#  'CASSLGTASSYNEQFF': [],
#  'CASSLDRGSSYEQYF': [],
#  'CASSLDRTSGNTIYF': [],
#  'CASSPRAATGELFF': [],
#  'CASSLSGGRETQYF': [],
#  'CASSRKPNYEQYF': [],
#  'CASSIGVANTGELFF': [],
#  'CASSDTGDEQYF': [],
#  'CASSSEGAGYGYTF': [],
#  'CASSPTGAYEQYF': [],
#  'CASSLSAGSYEQYF': [],
#  'CASSFETGSQHF': [],
#  'CASSYGTLHTDTQYF': [],
#  'CASSLSGGYQETQYF': [],
#  'CASSLAPGRTDTQYF': [],
#  'CASSRTGNNEQFF': [],
#  'CASSFSGSNEQFF': [],
#  'CASSPGTGTIDTQYF': [],
#  'CASSLAGTRTGELFF': [],
#  'CASRITGFYEQYF': [],
#  'CASSSTSGRAHYEQYF': [],
#  'CASSLSGSGLPYEQYF': [],
#  'CASSVGEKLFF': [],
#  'CASSLDISPYEQYF': [],
#  'CASSPGTGVYGYTF': [],
#  'CASSLGGAQNTEAFF': [],
#  'CASGLGQQETQYF': [],
#  'CASSLSGGGYQPQHF': [],
#  'CASSLEVLAGANEQFF': [],
#  'CASSLGTSSGANVLTF': [],
#  'CASSPRQGAYEQYF': [],
#  'CASSLGSSYEQYF': [],
#  'CASSTRGNQPQHF': [],
#  'CASSPAGLDTEAFF': [],
#  'CASSRTSGSLYEQFF': [],
#  'CASSPPVTDTQYF': [],
#  'CASSPLGNGYEQYF': [],
#  'CASSPLQGASQPQHF': [],
#  'CASSPNPSGNTIYF': [],
#  'CASSPGENPYEQYF': [],
#  'CASSSAPGNEQFF': [],
#  'CASSQGQADTQYF': [],
#  'CASSMGLAVYNEQFF': [],
#  'CASSPTTGSGANVLTF': [],
#  'CASSIGGSGQPQHF': [],
#  'CASSMAGGLSGTGELFF': [],
#  'CASSIRDSQETQYF': [],
#  'CASTGLAGGNEQFF': [],
#  'CASKGTVGYEQYF': [],
#  'CASSPRQGGETQYF': [],
#  'CASVSGELFF': [],
#  'CASSLDQRQETQYF': [],
#  'CASRTGPAETQYF': [],
#  'CASSLGGRHNEQFF': [],
#  'CASSTDRNEQFF': [],
#  'CASSPTSGSTTEAFF': [],
#  'CASSSLAGFTDTQYF': [],
#  'CASRGRSGANVLTF': [],
#  'CASSEIGETQYF': [],
#  'CASSGTSGSGTYNEQFF': [],
#  'CASRDYNEQFF': [],
#  'CASKVDRGEQYF': [],
#  'CASSFSPSYNEQFF': [],
#  'CASSVAGAGGNEQFF': [],
#  'CASSFIQSSYNEQFF': [],
#  'CASSLGGYDETQYF': [],
#  'CASSLEGTGDYGYTF': [],
#  'CASSLAGGDIQYF': [],
#  'CASSQGSYNQPQHF': [],
#  'CASSLEGVGYEQYF': [],
#  'CASSFSYEQYF': [],
#  'CASSLLIQPQHF': [],
#  'CASSLLGAGATNEKLFF': [],
#  'CASSFASGSSYNEQFF': [],
#  'CASGLGLVEQYF': [],
#  'CASTSGRPYEQYF': [],
#  'CASSLRLAREQYF': [],
#  'CASSLVGYNEQFF': [],
#  'CASSQDRGNEQYF': [],
#  'CASSLRPGSSYEQYF': [],
#  'CASSLADEKLFF': [],
#  'CSAGDKYEQYF': [],
#  'CSAPRGHEQYF': [],
#  'CSASKADTQYF': [],
#  'CSAKVVAGYTF': [],
#  'CASSFSRERGTDTQYF': [],
#  'CASSLKAGELFF': [],
#  'CASSLGDEQFF': [],
#  'CASSLDGFGANVLTF': [],
#  'CASSLSGYNEQFF': [],
#  'CASSITGTGELFF': [],
#  'CASSLATSGQETQYF': [],
#  'CASSTQGNQPQHF': [],
#  'CASRLAGDTGELFF': [],
#  'CASIQRGTDTQYF': [],
#  'CASSIGLVDEQFF': [],
#  'CASRMTGTYEQYF': [],
#  'CASSMGGGAYEQYF': [],
#  'CASSIQGAYGYTF': [],
#  'CASRNRGGSYNEQFF': [],
#  'CASRGQGSRQPQHF': [],
#  'CASRVAGASTDTQYF': [],
#  'CASRLAGASDTQYF': [],
#  'CASGSTGASTDTQYF': [],
#  'CASGQGNEQFF': [],
#  'CASSPSAGRETQYF': [],
#  'CASSPRLATGELFF': [],
#  'CASSPRGTDTQYF': [],
#  'CASSLPRQGGSYNEQFF': [],
#  'CASSPTSGSRIEQFF': [],
#  'CASSPDSYEQYF': [],
#  'CASSQGQGPYEQYF': [],
#  'CASSLGQDEKLFF': [],
#  'CASSLGTGISGETQYF': [],
#  'CASSFGPNYEQYF': [],
#  'CASSFLAGGPGELFF': [],
#  'CASSFPSYEQYF': [],
#  'CASSLKGQGHEKLFF': [],
#  'CASSRDGHTEAFF': [],
#  'CASSLGPISNQPQHF': [],
#  ...}

# %% [markdown]
# ### Background

# %%
for i in range(100):
    
    print(i)

    starttime = timer()
    background = sample_cdr3s(s=len(example))
    print(f'Time elapsed SAMPLING: {np.round(timer()-starttime, 2)} seconds')

    res = find_neighbors_within_radius(
        query=list(seq_with_nbrs.keys()),
        dataset=background
        )

    # starttime = timer()
    # index = IvfIndex(hasher=hasher, n_centroids=1000, n_probe=10)
    # index.add(background)
    # print(f'Time elapsed BUILDING the index: {np.round(timer()-starttime, 2)} seconds')

    # starttime = timer()
    # # res = [index.radius_search(seq, r=0.2, exclude_self=True) for seq in bg_counts]
    # counts = pool.map(search_radius, background)
    # res = dict(zip(list(seq_with_nbrs.keys()),counts))
    # print(f'Time elapsed SEARCHING the index: {np.round(timer()-starttime, 2)} seconds')
    
    for i in bg_counts:
        bg_counts[i].append(res[i])
# Out:
# 0
# Time elapsed SAMPLING: 1.01 seconds
# Time elapsed BUILDING the index: 5.58 seconds
# Time elapsed SEARCHING the index: 11.0 seconds
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 26
#      14 # starttime = timer()
#      15 # index = IvfIndex(hasher=hasher, n_centroids=1000, n_probe=10)
#      16 # index.add(background)
#    (...)
#      22 # res = dict(zip(list(seq_with_nbrs.keys()),counts))
#      23 # print(f'Time elapsed SEARCHING the index: {np.round(timer()-starttime, 2)} seconds')
#      25 for i in bg_counts:
# ---> 26     bg_counts[i].append(res[i])
#
# KeyError: 'CASSLLNLGTDTQYF'

# %% [markdown]
# ### Refinement searching

# %%
def nneighbors(index, seq, r, exclude_self):
    return len(index.radius_search(seq, r=r, exclude_self=exclude_self))

def avg_knn_distance(hasher, query, dataset, k:int=100):

    # Index configuration
    index = IvfIndex(hasher=hasher, n_centroids=1000, n_probe=50)
    
    # Build index
    starttime = timer()
    index.add(dataset)
    print(f'Time elapsed BUILDING the index: {np.round(timer()-starttime, 2)} seconds')

    starttime = timer()
    res = index.knn_search(query, k=k)
    print(f'Time elapsed SEARCHING the index: {np.round(timer()-starttime, 2)} seconds')

    return res

def find_neighbors_within_radius(query, dataset, hasher, ncpus:int=1, k:int=150, p:int=3):
    '''
    Parameters
    ----------
    dataset
        Vectors to store on index.
    '''
    
    pool = Pool(ncpus)
    
    # Index configuration
    index = IvfIndex(hasher=hasher, n_centroids=k, n_probe=p)
    
    # Build index
    starttime = timer()
    index.add(dataset)
    print(f'Time elapsed BUILDING the index: {np.round(timer()-starttime, 2)} seconds')
    
    starttime = timer()
    counts = [nneighbors(index, seq, r=0.1, exclude_self=True) for seq in query]
    neighbors = dict(zip(query,counts))
    print(f'Time elapsed SEARCHING the index: {np.round(timer()-starttime, 2)} seconds')

    return neighbors

# %%
# FOREGROUND
def find_foreground_neighbors(
    repertoire,
    hasher=None,
    eliminate_singlets:bool=True
    ):
    # If none provided, use default
    if hasher is None:
        hasher = Cdr3Hasher(m=256).fit()
    fg = find_neighbors_within_radius(query=repertoire, dataset=repertoire, hasher=hasher)
    if eliminate_singlets:
        return {i:fg[i] for i in fg if fg[i] > 0}
    else:
        return fg

def neighbor_significance(
    foreground_counts:dict,
    repertoire_size:int,
    background
    ):
    # Sequences
    q = list(foreground_counts.keys())
    # Find n neighbors of query in background
    bg = find_neighbors_within_radius(hasher=hasher, query=q, dataset=background)
    # Neighbor counts
    n_f = list(bg.values()) # in foreground
    n_b = list(foreground_counts.values()) # in background
    # Hypergeometric testing
    n = repertoire_size
    M = nc + n
    pvals = {i:hypergeom.sf(i, M, n, i+j) for i,j in zip(n_f,n_g)}
    return pd.DataFrame({'sequence':q, 'fg_n':n_f, 'bg_n':n_b, 'pvalue':pvals})

# %%
nf = find_foreground_neighbors(example)
# Out:
# Time elapsed HASHING: 4.18 seconds
# Time elapsed BUILDING the index: 4.67 seconds
# Time elapsed SEARCHING the index: 44.29 seconds

# %%
control = sample_cdr3s(100000)
sign = neighbor_significance(nf, control)
# Out:
# Time elapsed HASHING: 2.49 seconds
# Time elapsed BUILDING the index: 2.96 seconds
# Time elapsed SEARCHING the index: 15.1 seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 control = sample_cdr3s(100000)
# ----> 2 sign = neighbor_significance(nf, control)
#
# Cell In[21], line 28, in neighbor_significance(foreground_counts, background)
#      26 n_b = list(foreground_counts.values()) # in background
#      27 # Hypergeometric testing
# ---> 28 n = len(repertoire)
#      29 M = nc + n
#      30 pvals = {i:hypergeom.sf(i, M, n, i+j) for i,j in zip(n_f,n_g)}
#
# NameError: name 'repertoire' is not defined

# %%
from scipy.stats import hypergeom

def adaptive_sampling(repertoire, nc):
    '''
    repertoire
        Foreground repertoire.
    nc
        Number of sequences to sample from the background.
    '''
    
    starttime = timer()
    control = sample_cdr3s(s=nc)
    print(f'Time elapsed SAMPLING: {np.round(timer()-starttime, 2)} seconds')

    hasher = Cdr3Hasher(m=256).fit()
    
    fg = find_neighbors_within_radius(hasher=hasher, query=repertoire, dataset=repertoire)
    tn = {i:fg[i] for i in fg if fg[i] > 0}
    q = list(tn.keys())

    bg = find_neighbors_within_radius(hasher=hasher, query=q, dataset=control)

    n = len(repertoire)
    M = nc + n

    pvals = {i:hypergeom.sf(tn[i], M, n, tn[i]+bg[i]) for i in tn}

    seq = list(tn.keys())
    fg_n = list(tn.values())
    bg_n = list(bg.values())
    p = list(pvals.values())

    return pd.DataFrame({'sequence':seq, 'fg_n':fg_n, 'bg_n':bg_n, 'pvalue':p})

data = adaptive_sampling(example, 10000)


# def hypergeom_test(fg_n, bg_n, fg_total, bg_total):

# fg_total = len(example)
# bg_total = len(control)

# for seq in example[:100]:
#     fg_n = foreground[seq]
#     bg_n = background[seq]
#     if fg_n > 1:
#         pval = hypergeom.sf(fg_n, fg_total+bg_total, fg_total, fg_n+bg_n)
#         print(seq, pval
# Out:
# Time elapsed SAMPLING: 1.28 seconds
# Time elapsed HASHING: 3.97 seconds
# Time elapsed BUILDING the index: 4.43 seconds
# Time elapsed SEARCHING the index: 44.82 seconds
# Time elapsed HASHING: 0.25 seconds
# Time elapsed BUILDING the index: 0.32 seconds
# Time elapsed SEARCHING the index: 3.5 seconds

# %%
data[data.pvalue > .050]
# Out:
#               sequence  fg_n  bg_n    pvalue
# 2        CASSTTGGYEQYF     9     1  0.540824
# 4       CASSLGGGTDTQYF    33     1  0.123687
# 5       CASSLGLAGNEQFF    21     2  0.597899
# 21     CASSSRRGSTDTQYF     7     2  0.903247
# 47      CASSLAGSNQPQHF    45     1  0.059146
# ...                ...   ...   ...       ...
# 63884     CASSQIRYEQYF     3     1  0.782032
# 63887      CASSQKETQYF    24     1  0.215085
# 63900      CASSSLNQQYF     1     1  0.884326
# 63902     CASSQDRGEQYF    10     1  0.508582
# 63911   CASASRTDIYGYTF     1     1  0.884326
#
# [6578 rows x 4 columns]

# %%
foreground, background, p = test

data = pd.DataFrame(
    {'sequence':list(foreground.keys()), 'fg_n':list(foreground.values()), 'bg_n':list(background.values()), 'pvalue':p}
    )

data = data[data.pvalue < .05]
data.sort_values(by='pvalue')
# Out:
#               sequence  fg_n  bg_n    pvalue
# 32996  CASSQDPGVNTEAFF     2     0  0.000000
# 40116   CATSRGEGQETQYF     2     0  0.000000
# 40115   CATSRDRTGYEQYF     1     0  0.000000
# 40114  CASSGRLAARETQYF     1     0  0.000000
# 40113     CASSVEGYEQFF     1     0  0.000000
# ...                ...   ...   ...       ...
# 16976     CASSSITDTQYF    23    14  0.049426
# 10971   CASSLSGQAYEQYF    23    14  0.049426
# 16192    CASSLAGKETQYF    23    14  0.049426
# 27857    CASSSTGTYEQYF    23    14  0.049426
# 305       CASSLGVYEQYF    23    14  0.049426
#
# [40081 rows x 4 columns]

# %%
print('configuration 1')
r1 = find_neighbors_within_radius(
    query=example, 
    dataset=example,
    hasher=hasher,
    k=1000,
    p=10
    )

print('configuration 2')
r2 = find_neighbors_within_radius(
    query=example, 
    dataset=example,
    hasher=hasher,
    k=100,
    p=1
    )
# Out:
# configuration 1
# Time elapsed BUILDING the index: 4.71 seconds
# Time elapsed SEARCHING the index: 30.68 seconds
# configuration 2
# Time elapsed BUILDING the index: 1.07 seconds
# Time elapsed SEARCHING the index: 24.9 seconds

# %%
foreground = find_neighbors_within_radius(
    hasher=hasher,
    query=example,
    dataset=example
    )
# Out:
# Time elapsed HASHING: 0.84 seconds
# Time elapsed BUILDING the index: 4.95 seconds
# Time elapsed SEARCHING the index: 31.45 seconds

# %%
starttime = timer()
control = sample_cdr3s(s=500000)
print(f'Time elapsed SAMPLING: {np.round(timer()-starttime, 2)} seconds')

background = find_neighbors_within_radius(
    hasher=hasher,
    query=example,
    dataset=control
    )
# Out:
# Time elapsed SAMPLING: 1.13 seconds
# Time elapsed HASHING: 8.0 seconds
# Time elapsed BUILDING the index: 16.77 seconds
# Time elapsed SEARCHING the index: 66.71 seconds

# %%
[i for i in foreground if foreground[i] > 0]
# Out:
# ['CASSLSGAGNTIYF',
#  'CASSLLAGPYNEQFF',
#  'CASSTTGGYEQYF',
#  'CASSLLNLGTDTQYF',
#  'CASSLGGGTDTQYF',
#  'CASSLGLAGNEQFF',
#  'CASSLGAGGETQYF',
#  'CASSYVGGGNQPQHF',
#  'CASSLMDLNTGELFF',
#  'CASSRDRNYGYTF',
#  'CASSRTGGTNTEAFF',
#  'CASSRAGFYGYTF',
#  'CASSFGGAEQFF',
#  'CASSLEGIGNQPQHF',
#  'CASTSANTDTQYF',
#  'CASSLTAEQFF',
#  'CASSLSAEQFF',
#  'CASSLIPKGLNTGELFF',
#  'CASSRDRVSYEQYF',
#  'CASSFGGSSYEQYF',
#  'CASSFDSYSNQPQHF',
#  'CASSSRRGSTDTQYF',
#  'CASSSSATISYNEQFF',
#  'CASSLAGTLEKLFF',
#  'CASSTLGSTNEKLFF',
#  'CASSFPGTEAFF',
#  'CASSLGGGNTIYF',
#  'CASSLRTGATGELFF',
#  'CASSLGSGSYEQYF',
#  'CASSLRLGDTGELFF',
#  'CASSLAAGGPEAFF',
#  'CASSLVAGGSNTGELFF',
#  'CASSLLADTSTDTQYF',
#  'CASRSGANQETQYF',
#  'CASWTSGDEQFF',
#  'CASSLGGISDTQYF',
#  'CASSGGQGSNQPQHF',
#  'CASSLAQGRNYGYTF',
#  'CASSLGGANTQYF',
#  'CASSAPQGAYEQYF',
#  'CASSFSQGARTYEQYF',
#  'CASSLGVSHSYEQYF',
#  'CASSLRENTEAFF',
#  'CASSLEGRGETQYF',
#  'CASSLAGTGVYEQYF',
#  'CASSLGGGYGYTF',
#  'CASSLQGSPNYGYTF',
#  'CASSPTGTDTQYF',
#  'CASSLRPGQTYEQYF',
#  'CASSLAGSNQPQHF',
#  'CASSLQGEYYEQYF',
#  'CASSLLAQGEQYF',
#  'CASSFPPYEQYF',
#  'CASSLTSPSGANVLTF',
#  'CASSHTSTDTQYF',
#  'CASSLATSGSRYEQYF',
#  'CASRTGVEQYF',
#  'CASSLTLNTEAFF',
#  'CASSRTGLTNEKLFF',
#  'CASSLADSSNQPQHF',
#  'CASSLVWANTEAFF',
#  'CASRKLAQETQYF',
#  'CASSLEGNSGNTIYF',
#  'CASSLVGTSSSYNEQFF',
#  'CASSLERGGNTEAFF',
#  'CASSLGVNEQFF',
#  'CASSLVAGKSYEQYF',
#  'CASSFMNTEAFF',
#  'CASSGLGRLLNEQFF',
#  'CASSKQGREQYF',
#  'CASSIGTATGELFF',
#  'CASSGTVNTEAFF',
#  'CASSLGPETQYF',
#  'CASSLRPLYEQYF',
#  'CASSLGPYNEQFF',
#  'CASSLGPGYNEQFF',
#  'CASSLSTNEKLFF',
#  'CASSTGTFYNEQFF',
#  'CASSLTAGSSYEQYF',
#  'CASRSGSGTYNEQFF',
#  'CASSFGTHSNQPQHF',
#  'CASSLEGIGTDTQYF',
#  'CASSEGQGRNTIYF',
#  'CASSPAYEQYF',
#  'CASSSRGSQETQYF',
#  'CASSLVADSYGYTF',
#  'CASSLGASGQPQHF',
#  'CASSLQPSSSYEQYF',
#  'CASSRQGALGYTF',
#  'CASSLGGNTIYF',
#  'CASSSRGSGNTIYF',
#  'CASSSGQMNTEAFF',
#  'CASSWGTVSYEQYF',
#  'CASSFSGTLYEQYF',
#  'CASSRQGEDYGYTF',
#  'CASSSGLREAFF',
#  'CASSLGASNQPQHF',
#  'CASSLATGLTYGYTF',
#  'CANSYRVQETQYF',
#  'CASSQSPGPYNEQFF',
#  'CASSLGPGSSYEQYF',
#  'CASSPRQGRGEQYF',
#  'CASSFRDPYEQYF',
#  'CASSLILDAEAFF',
#  'CASSLSREGPYEQYF',
#  'CASSLGGQPQHF',
#  'CASSFLFQETQYF',
#  'CASSLDGSGELFF',
#  'CASSHRRGSEKLFF',
#  'CASSLQGGGDTQYF',
#  'CASSQDRGTYNEQFF',
#  'CASSLEGGAYNEQFF',
#  'CASSLERYSYNEQFF',
#  'CASSLSDYNEQFF',
#  'CASSTGHSSYEQYF',
#  'CASSLAHNEQFF',
#  'CASSSQGGSSYNEQFF',
#  'CASTLAVNTGELFF',
#  'CASSLGQYEQYF',
#  'CASSWGGGLEQYF',
#  'CASKASSYNEQFF',
#  'CASSLEGSDYGYTF',
#  'CASSSVYGYTF',
#  'CASSQNEQYF',
#  'CASSRNNEQFF',
#  'CASSLGTAPMNTEAFF',
#  'CASSPPGELFF',
#  'CASSPGLAGVNEQFF',
#  'CASSLVSYEQYF',
#  'CASSPGGMNTEAFF',
#  'CASSPGQGGQPQHF',
#  'CASSSIQGGTDTQYF',
#  'CASSPRDGKLFF',
#  'CASSPGRKNTEAFF',
#  'CASSPVMDTQYF',
#  'CASSLDFLYEQYF',
#  'CASSLASVAEQYF',
#  'CASSPGGTQYF',
#  'CASSLVGNTEAFF',
#  'CASSLAAGLFQETQYF',
#  'CASSLEGASTDTQYF',
#  'CASSPTGGKTEAFF',
#  'CASSPATEAFF',
#  'CASSLGLAETDTQYF',
#  'CASSPRTANTGELFF',
#  'CASSPRGNTGELFF',
#  'CASSPGQGMNGYTF',
#  'CASSLAGSTEAFF',
#  'CASSSAGESSTDTQYF',
#  'CASSLGVDEQFF',
#  'CASSLAGTGVTDTQYF',
#  'CASSPPVIETQYF',
#  'CASSPRTSGRNNEQFF',
#  'CASSPLGQGSSYEQYF',
#  'CASSRTSGLYEQYF',
#  'CASSPLRGGETQYF',
#  'CASSPPGQGYNEQFF',
#  'CASSLTQETQYF',
#  'CASSHGQGGNQPQHF',
#  'CASRPGTSGSTDTQYF',
#  'CASSLWSYNEQFF',
#  'CASSPGTRYNEQFF',
#  'CASSILPQGSSYNEQFF',
#  'CASSSALYEQYF',
#  'CASSPPRGLDTQYF',
#  'CASSPDRSYEQYF',
#  'CASSPDRLGYEQYF',
#  'CASSPASTNEKLFF',
#  'CASSPFRGYEQYF',
#  'CASSQPTGGYEQYF',
#  'CASSLTSGRVGEQYF',
#  'CASSFDDDGYTF',
#  'CASSRGIMNTEAFF',
#  'CASSLVVATNEKLFF',
#  'CASTDKGNEQFF',
#  'CASSLGGYDTDTQYF',
#  'CASSSGPVEQYF',
#  'CASSSDRVYGYTF',
#  'CASSFQGVSNQPQHF',
#  'CASSLEPGVQPQHF',
#  'CASSPIGGDEQYF',
#  'CASSLEARNTEAFF',
#  'CASSPGQGAYTGELFF',
#  'CASSPIGQGLGEQYF',
#  'CASSPEGEAFF',
#  'CASSPGTGRTEAFF',
#  'CASSPIAGLTTGELFF',
#  'CASSQSEETQYF',
#  'CASSRGYEQYF',
#  'CASSLGGLGTDTQYF',
#  'CASSLSGSGVWNEQFF',
#  'CASLTSGKTDTQYF',
#  'CASSLRTGNQPQHF',
#  'CASGTSGSHEQYF',
#  'CASSPVQETQYF',
#  'CASSPGRTNTGELFF',
#  'CASSSRRETGELFF',
#  'CASSLSRTYEQYF',
#  'CASSASGSKNQPQHF',
#  'CASSLTDLTYEQYF',
#  'CASSLGILAGRSYEQYF',
#  'CASSLEETQYF',
#  'CASRRSGSNYGYTF',
#  'CASSFTGNEQFF',
#  'CASSLAQVSYNEQFF',
#  'CASSPVTSTDTQYF',
#  'CASSPNREKLFF',
#  'CASSPFVAPYNEQFF',
#  'CASSPLDTNSGNTIYF',
#  'CASSLSDGNTEAFF',
#  'CASSLGRRTETQYF',
#  'CASSLGPTSNQPQHF',
#  'CASSFRQTYNEQFF',
#  'CASSRLAGNNEQFF',
#  'CASSPISGGNTEAFF',
#  'CASSPLVGELFF',
#  'CASSQKGTGANVLTF',
#  'CASTGVAEQFF',
#  'CASSLDRAVYGYTF',
#  'CASSQTSGIVNEQFF',
#  'CASSYRTGGSGYEQYF',
#  'CASSLGDRANQPQHF',
#  'CASSLGRVNQPQHF',
#  'CASSFTANTEAFF',
#  'CASSPLAVFSYNEQFF',
#  'CASSPRGRTSTDTQYF',
#  'CASSLGLAGGETQYF',
#  'CASSPDRGGNEQFF',
#  'CASSLVEGLGEQYF',
#  'CASSLVGGMGTGELFF',
#  'CASSLGAGPYEQYF',
#  'CASSPSRGRTGELFF',
#  'CASSPGRGETQYF',
#  'CASSSRGQGTDTQYF',
#  'CASSPRLAGGYEQFF',
#  'CASSPGPGANVLTF',
#  'CASSPKRTTDTQYF',
#  'CASSRDSINTEAFF',
#  'CASSLAVFYEQYF',
#  'CASSSQTGLNTEAFF',
#  'CASSTDRNTEAFF',
#  'CASSIPGGGEQYF',
#  'CASSLYGYEQYF',
#  'CASSQGASGQETQYF',
#  'CASSPLRSSYEQYF',
#  'CASSPALRDTEAFF',
#  'CASSSLGSPSYNEQFF',
#  'CASSLLVQETQYF',
#  'CASSLGLAVSTDTQYF',
#  'CASSLTAYTGELFF',
#  'CASSSQPTDTQYF',
#  'CASSPGGSYNEQFF',
#  'CASSQWDRGNEQFF',
#  'CASTPQTGGNTEAFF',
#  'CASSWGSYEQYF',
#  'CASSLWDRETDTQYF',
#  'CASSRLAGGINEQFF',
#  'CASNLEGARSYEQYF',
#  'CASSLGVPAYEQYF',
#  'CASSLGAGASYEQYF',
#  'CASSYTDTQYF',
#  'CASSLGVQAEAFF',
#  'CASSLSTYEQYF',
#  'CASSRSGGGYTF',
#  'CASSPPGPQRYF',
#  'CASSRDLGETQYF',
#  'CASSPQGYEQYF',
#  'CASSLNRAQETQYF',
#  'CASSPPVGGSGNTIYF',
#  'CASSLAAGQNTEAFF',
#  'CASSLERENTEAFF',
#  'CASSLFKNTEAFF',
#  'CASSLTGQGAEAFF',
#  'CASSLGRLNTEAFF',
#  'CASSFGTTGELFF',
#  'CASSLGTGGSGANVLTF',
#  'CASSLAQGPYEQYF',
#  'CASSLVGGYTF',
#  'CASSLRQDNEQFF',
#  'CASSPDSSSYNEQFF',
#  'CASSRLAGRYNEQFF',
#  'CASSLMSSGSSYNEQFF',
#  'CASSLSGRGTDTQYF',
#  'CASSLGPNTGELFF',
#  'CASSPVAGGHNEQFF',
#  'CASSPLDTGELFF',
#  'CASSLYGGSQPQHF',
#  'CASSLAGGGRQPQHF',
#  'CASTRADTQYF',
#  'CASSSDTYSYEQYF',
#  'CASSLLGTGANVLTF',
#  'CASSLASGSVGEQFF',
#  'CASSLEGTGANVLTF',
#  'CASSEGRGRGTDTQYF',
#  'CASSLSEGSYNEQFF',
#  'CASQDTSSYNEQFF',
#  'CASSPNRGRGYNEQFF',
#  'CASSLRLREGYTF',
#  'CASKDRGAGELFF',
#  'CASSAVDTGELFF',
#  'CASSLGTGRSSYEQYF',
#  'CASSLATGGDYGYTF',
#  'CASSIVSTTNEKLFF',
#  'CASSLAGGYEQYF',
#  'CASSFSDGVSYEQYF',
#  'CASSLGVYEQYF',
#  'CASSGTLVGPPYEQYF',
#  'CASSEGAGNTIYF',
#  'CASSLSIIGNQPQHF',
#  'CASSLQSSGANVLTF',
#  'CASSPQTAGNTIYF',
#  'CASSPLATSTDTQYF',
#  'CASSPRTGNTGELFF',
#  'CASSPEETQYF',
#  'CASSLEGARGNQPQHF',
#  'CASSPVTGGITEAFF',
#  'CASSLGGGTEAFF',
#  'CASSQTGTVETQYF',
#  'CASSLAGRQPQHF',
#  'CASSLVPVGNEQFF',
#  'CASSLVTDTQYF',
#  'CASSLKGPGYGYTF',
#  'CASSLRGVTDTQYF',
#  'CASSFTRASTDTQYF',
#  'CASSEDRAADTQYF',
#  'CASSEIGLAGQETQYF',
#  'CASSLGTANTGELFF',
#  'CASGAGYTGELFF',
#  'CASSELTGNIQYF',
#  'CASSPGSEQYF',
#  'CASSLSSGQTYEQYF',
#  'CASSLGPQPQHF',
#  'CASSPTDRDQPQHF',
#  'CASSPVTSGTGELFF',
#  'CASSLPLAGGNEQFF',
#  'CASSPQQGPDTGELFF',
#  'CASSPRGVYNEQFF',
#  'CASSVELYNEQFF',
#  'CASSPRRNEQFF',
#  'CASSPRGLSNQPQHF',
#  'CASSKTGGGNQPQHF',
#  'CASEGGGTYEQYF',
#  'CASTEGVGNEQFF',
#  'CASSLELGEQFF',
#  'CASSLRLDQETQYF',
#  'CASSLGGINTGELFF',
#  'CASSTGTGGLLETQYF',
#  'CASSLAGQYNEQFF',
#  'CASSLGTGYSTDTQYF',
#  'CASSLSGGNGYTF',
#  'CASGLGPAYEQYF',
#  'CASSDGGASTDTQYF',
#  'CASERGPGELFF',
#  'CASRPTSGSYEQYF',
#  'CASSLSDSSGNTIYF',
#  'CASSLGQGPYEQYF',
#  'CASSYPPNEKLFF',
#  'CASSSPGQGFNEQFF',
#  'CASSLALGANTEAFF',
#  'CASSRGQGRYEQYF',
#  'CASSFGENTEAFF',
#  'CASSLEGLGNQPQHF',
#  'CASSPRPEETQYF',
#  'CASSLFGETQYF',
#  'CASSPRDRVNEQFF',
#  'CASSPGLAEGETQYF',
#  'CASSQPMRYEQYF',
#  'CASGLGQGADTQYF',
#  'CASAVAGGPEQFF',
#  'CASGLGSYNEQFF',
#  'CASRKNRGSTGELFF',
#  'CASSKGQGDEKLFF',
#  'CASSETRQGSTEAFF',
#  'CASSGGTSGYNEQFF',
#  'CASSDLGQETQYF',
#  'CASSEAGVGNTIYF',
#  'CASSLSGGNNEQFF',
#  'CASSLLPRQGRTYNEQFF',
#  'CASSLSGRPTDTQYF',
#  'CASLSENYEQYF',
#  'CASSLSPDRVETQYF',
#  'CASSLVSSGNTIYF',
#  'CASSVLAGDYEQYF',
#  'CASSVGTAAYEQYF',
#  'CASSEALGVNYGYTF',
#  'CASSSDGSGQPQHF',
#  'CASSREVAYEQYF',
#  'CASREGISNQPQHF',
#  'CASARDLNTEAFF',
#  'CASSPTGTNYGYTF',
#  'CASSPGGLGYEQYF',
#  'CASSTQETQYF',
#  'CASSLGLVSYNEQFF',
#  'CASSLGQGQPQHF',
#  'CASSPRGGTSYNEQFF',
#  'CASSLIGGTGGTGELFF',
#  'CASGLDYQPQHF',
#  'CASGLRGDEQFF',
#  'CASSLASGEAFF',
#  'CASRILASTDTQYF',
#  'CASSSLSTQETQYF',
#  'CASSFGDRTDTQYF',
#  'CASSLSDSPYEQYF',
#  'CASSLDPNEKLFF',
#  'CASSPDGPYGYTF',
#  'CASSPSGSSSGANVLTF',
#  'CASSERGGGNEQFF',
#  'CASSAGVANQPQHF',
#  'CASSGGENYGYTF',
#  'CASSLGTGAYEQYF',
#  'CASSLSTVNTEAFF',
#  'CASSLWGGQPQHF',
#  'CASSFMANTGELFF',
#  'CASRLTGDEQFF',
#  'CASRGGETQYF',
#  'CASSRQGADTDTQYF',
#  'CASSPPGLLNEQFF',
#  'CASSDRGGDQPQHF',
#  'CASSPPGGGYEQYF',
#  'CASSSGLGSDTQYF',
#  'CASSLDLALGTDTQYF',
#  'CASSMSGSTGELFF',
#  'CASGLGAGTGYGYTF',
#  'CASTGMNTEAFF',
#  'CASGGDRGNTEAFF',
#  'CASGLTGDEQFF',
#  'CASSLQGRDTGELFF',
#  'CASSQSESDEQYF',
#  'CASSIGTSLNEQFF',
#  'CASSLGLTAYEQYF',
#  'CASSLNEKLFF',
#  'CASSVTGMINTGELFF',
#  'CASSQINEKLFF',
#  'CATRWGDEQFF',
#  'CASSVLQMNTEAFF',
#  'CASSGGSRETQYF',
#  'CASSLAAGKEQYF',
#  'CASSTGGDNQPQHF',
#  'CASSRTSDEQFF',
#  'CASSPPSQGETQYF',
#  'CASSSILAGGEQFF',
#  'CASSLTGTGNYNEQFF',
#  'CASSLWGGSSYNEQFF',
#  'CASGQGGNTEAFF',
#  'CASSQGANTEAFF',
#  'CASSLVGTLNQPQHF',
#  'CASSLTGTGPYEQYF',
#  'CASSFGDYYEQYF',
#  'CASSLGRTYEQYF',
#  'CASSEWRTEAFF',
#  'CASSGRVSEAFF',
#  'CASKGKQEAFF',
#  'CASREMNTEAFF',
#  'CASSPPGRDEQYF',
#  'CASSPKPGGGADTQYF',
#  'CASSPSVGGGYTF',
#  'CASSPLSMNTEAFF',
#  'CASSPGNSYGYTF',
#  'CASSSPGRNEQFF',
#  'CASSLGAGNEQFF',
#  'CASSLTGSGNTIYF',
#  'CASSLNRGDTDTQYF',
#  'CASSLEVNYGYTF',
#  'CASSLTGVNTEAFF',
#  'CASSLRGGLTDTQYF',
#  'CASSLEGGSGETQYF',
#  'CASSLEREGTYEQYF',
#  'CASSLGQISNQPQHF',
#  'CASSSRTGYTEAFF',
#  'CASSLEGQGSQPQHF',
#  'CASSLTENTEAFF',
#  'CASSLQGMNTEAFF',
#  'CASSRGAYNEQFF',
#  'CASSRVVQETQYF',
#  'CASSLGQGYEQYF',
#  'CASSLLTGNNQPQHF',
#  'CASSLGQLNTEAFF',
#  'CASSLEVSGGSYEQYF',
#  'CASSQEETQYF',
#  'CASSLQGDSNQPQHF',
#  'CASSLKGDRNTEAFF',
#  'CASSLAGETQYF',
#  'CASSNLPDTQYF',
#  'CASGLGSIQETQYF',
#  'CASGRDYYEQYF',
#  'CASSQGTSGYNEQFF',
#  'CASSATGGGEQFF',
#  'CASSLRGAGNIQYF',
#  'CASSTRTDNEQFF',
#  'CASSQGRGNTEAFF',
#  'CASRGGRSSYNEQFF',
#  'CASSGGSANTGELFF',
#  'CASRDRGRNEQFF',
#  'CASSDLLLQPQHF',
#  'CASIGGRAADTQYF',
#  'CASEGHGNQPQHF',
#  'CASSPSSYEQYF',
#  'CASSPGTGGQPQHF',
#  'CASSRASGVYEQYF',
#  'CASSALSGSGNTIYF',
#  'CASSPRRSYEQYF',
#  'CASSPGGGGGYEQYF',
#  'CASSPNRASYEQYF',
#  'CASSLWGMNQPQHF',
#  'CASSFLGSEQFF',
#  'CASSPTGGNSNQPQHF',
#  'CASSWGQENQPQHF',
#  'CASSLGALGTNEKLFF',
#  'CASTQRQGATNTEAFF',
#  'CASSPLGQGNTEAFF',
#  'CASGLNKNTEAFF',
#  'CASSPQGRNTGELFF',
#  'CASSLGHSTDTQYF',
#  'CASSGGQGSYNEQFF',
#  'CASSLTGYEQYF',
#  'CASSFSDGSYEQYF',
#  'CASSAVVGTYEQYF',
#  'CASSLHSLTYEQYF',
#  'CASGRDLNQPQHF',
#  'CASAQGYNQPQHF',
#  'CASALGGGTEAFF',
#  'CASSGGTGEYGYTF',
#  'CASSLSGPVGNTIYF',
#  'CASSFLRASYNEQFF',
#  'CASSPTGSTEAFF',
#  'CASSLVSNEQFF',
#  'CASSLGLAATDTQYF',
#  'CASGQGPYNEQFF',
#  'CASRKGPNYGYTF',
#  'CASAPMNTGELFF',
#  'CASGLSGAADTQYF',
#  'CASRTGGYNEQFF',
#  'CANSDNYNWPYEQYF',
#  'CASSGGRPDTQYF',
#  'CASSDRAGGPTEQFF',
#  'CASSSMGRGSGANVLTF',
#  'CASSAEYEQYF',
#  'CASSLEGRGNEKLFF',
#  'CASSPGANTGELFF',
#  'CASSLGGTDTQYF',
#  'CASSLREEQFF',
#  'CASSSTLETQYF',
#  'CASSSGHQYF',
#  'CASSPTGVRNEKLFF',
#  'CASREGNTGELFF',
#  'CASSLGQGPYYEQYF',
#  'CASSPTGGGYEQYF',
#  'CASSLVSSSEAFF',
#  'CASSQQDQETQYF',
#  'CASSPRQGAAQETQYF',
#  'CASSPSSAEAFF',
#  'CASSQKGGGYEQYF',
#  'CASAGDTEAFF',
#  'CASAHTGELFF',
#  'CASSLSGGTDTQYF',
#  'CASSYSSAGTSYEQYF',
#  'CASSFAGSYEQYF',
#  'CASSPVGSLEQYF',
#  'CASSLDATTDTQYF',
#  'CASMRTGSYEQYF',
#  'CASSAGQSTDTQYF',
#  'CASSDGAKNIQYF',
#  'CASSETAGANVLTF',
#  'CASSLGGQKETQYF',
#  'CASGVTDTQYF',
#  'CASASQSNQPQHF',
#  'CASSLAGGTRDEQFF',
#  'CASSSGLAGGYEQFF',
#  'CASSSSGSYEQYF',
#  'CASSFLAGVAGELFF',
#  'CASSLEGTGGEKLFF',
#  'CASSWESATNEKLFF',
#  'CASSLRGSGYNEQFF',
#  'CASSFRDRGQPQHF',
#  'CAGGIQETQYF',
#  'CASSPRDTQPQHF',
#  'CASSPPGGEDEQYF',
#  'CASSPLPTADTQYF',
#  'CASSLVGDEKLFF',
#  'CASSPLGTSPSYEQYF',
#  'CASSDKGSYEQYF',
#  'CASSLFQNTEAFF',
#  'CASGLEGNTEAFF',
#  'CASSLGSGSYNEQFF',
#  'CASSSTGPNQPQHF',
#  'CASSARVDYGYTF',
#  'CASSQRTGTYEQYF',
#  'CASSFLGGGNEQFF',
#  'CASSPAGGTGELFF',
#  'CASSLLESNEQFF',
#  'CASSPLGGGRTYNEQFF',
#  'CASSLVENTGELFF',
#  'CASSPLSEGYEQYF',
#  'CASSPLSGGTDTQYF',
#  'CASSPRSGLQETQYF',
#  'CASAVTGGGTEAFF',
#  'CASSPGQKNTEAFF',
#  'CASSFSGSSSYNEQFF',
#  'CASSLSWANEKLFF',
#  'CASTSGSQETQYF',
#  'CASTFGGLGYEQYF',
#  'CASSFGVHTEAFF',
#  'CASKIADTEAFF',
#  'CASTPSGINSPLHF',
#  'CASALRTGELFF',
#  'CASSENNEQFF',
#  'CASCPGFVGGYKQYF',
#  'CASSRLAGSTDTQYF',
#  'CASSFVTINEQFF',
#  'CASSLGGVRGYTF',
#  'CASSLGTSGKNEQYF',
#  'CASSPRQGPTEAFF',
#  'CASSPRQGMNTEAFF',
#  'CASSLTFSDTQYF',
#  'CASKGNEQFF',
#  'CASSPSSGSTEAFF',
#  'CASSPDRDGQPQHF',
#  'CASSQDEKLFF',
#  'CASSLLGQGNTEAFF',
#  'CASSPPGGSYNEQFF',
#  'CASSLGQGASTEAFF',
#  'CASSLGDTQYF',
#  'CASSLVLAGVRDTQYF',
#  'CASSLASTNTGELFF',
#  'CASSPGRTSTDTQYF',
#  'CASSLVIATTDTQYF',
#  'CASSLAGRATEAFF',
#  'CASSLASGPTDTQYF',
#  'CASSLGPSQETQYF',
#  'CASSLTGGDEKLFF',
#  'CASSEAGVSYNEQFF',
#  'CASRDSNTDTQYF',
#  'CASTGLAGNNEQFF',
#  'CASSVQGVTYEQYF',
#  'CASSLVGTSLNEQFF',
#  'CASGLVETQYF',
#  'CASGLAGGYGYTF',
#  'CASSLNGGELFF',
#  'CASSSGTSGPDTQYF',
#  'CASSELAGGRNEQFF',
#  'CASSLTGKNTEAFF',
#  'CASSITGGGNQPQHF',
#  'CASSLGSLAGEQYF',
#  'CASSLVSLGNEQFF',
#  'CASSLGGRQAYGYTF',
#  'CASSFTGDTEAFF',
#  'CASSINPYNEQFF',
#  'CASSITGSTDTQYF',
#  'CASSTPGGSGANVLTF',
#  'CASRSGGANTEAFF',
#  'CASSLGNTEAFF',
#  'CASSETGNYGYTF',
#  'CASSRLPSGREETQYF',
#  'CASSATGLSYNEQFF',
#  'CASSGTSGRNYNEQFF',
#  'CASKGGRSGANVLTF',
#  'CASSPGVVYEQYF',
#  'CASSPIGVANEKLFF',
#  'CASSPKRSSYEQYF',
#  'CASSPDRPTGELFF',
#  'CSARDLETQYF',
#  'CSARVRNEQFF',
#  'CSARLGNEQFF',
#  'CSRTRADTQYF',
#  'CSARLRNEQFF',
#  'CSASDSYEQYF',
#  'CSLAGVNEQYF',
#  'CSASLNTQYF',
#  'CASSLSMGLAGLEQFF',
#  'CASSLGLAGLGETQYF',
#  'CASSLLSGTYNEQFF',
#  'CASTPGGREVYGYTF',
#  'CASSLAGQVLYEQYF',
#  'CASSGTGGDTQYF',
#  'CASSSPGTGPYNEQFF',
#  'CASGLGSGNTEAFF',
#  'CASIPDRANTGELFF',
#  'CASSSPDTYEQYF',
#  'CASSPGFGDTQYF',
#  'CASSLTEGQPQHF',
#  'CASSLTSGSINEQFF',
#  'CASSLGGGGTDTQYF',
#  'CASSIGRANEQYF',
#  'CASSLDSYSNQPQHF',
#  'CASSPGPYNEQFF',
#  'CASRQEYEQYF',
#  'CASQGGTEAFF',
#  'CASKAGGELFF',
#  'CASRVAGRGTDTQYF',
#  'CASSPTGTEETQYF',
#  'CASSRLAGVTGELFF',
#  'CASSLAAMSYNEQFF',
#  'CASSPSGSHANEQFF',
#  'CASSLDSGAGELFF',
#  'CASSSTGTGLNEQFF',
#  'CASSPAGGNQPQHF',
#  'CASSLSAETQYF',
#  'CASSLGGSYNEQFF',
#  'CASSLGVRNTEAFF',
#  'CASGLNSYEQYF',
#  'CASGSSGGGNEQFF',
#  'CASSPGSDYEQYF',
#  'CASSPRSDEKLFF',
#  'CASSPGQARDEQYF',
#  'CASSQETGQETQYF',
#  'CASSSGLATGELFF',
#  'CASSFAGTSTDTQYF',
#  'CAHSPGTDTQYF',
#  'CASSFQQGGTDTQYF',
#  'CASREESYNEQFF',
#  'CASSQGGGWSNQPQHF',
#  'CSARYNEQFF',
#  'CSATSYEQYF',
#  'CSAKRATEAFF',
#  'CSASLVGEQYF',
#  'CSADRQETQYF',
#  'CASSLAVVGYNEQFF',
#  'CASSLLGSNEKLFF',
#  'CASSYTGLSSYEQYF',
#  'CASSLTGTGGEKLFF',
#  'CASSATGGNGYTF',
#  'CASSLVGNTYEQYF',
#  'CASSLGGLDEQFF',
#  'CASSLAGGVTEAFF',
#  'CASSLNRDTHEQYF',
#  'CASSPFGTDTQYF',
#  'CASGPSVDTQYF',
#  'CASGPGGGTEAFF',
#  'CASGGGTEAFF',
#  'CASSQLGLAGVGETQYF',
#  'CASSPQGSYNEQFF',
#  'CASSFGSGTSSYEQYF',
#  'CASSLGGGDGYTF',
#  'CASSIADTQYF',
#  'CASSLAGGQETQYF',
#  'CASSPRTGGVTYNEQFF',
#  'CASSIEGLAGNEQFF',
#  'CASSSLYEQFF',
#  'CASKTGAGANVLTF',
#  'CASSIRGNNQPQHF',
#  'CGTGTGNQPQHF',
#  'CASTREGRELFF',
#  'CASTGGPYEQYF',
#  'CASGSSGGSYNEQFF',
#  'CASSYGVSTDTQYF',
#  'CASSVGLAGAQYF',
#  'CASSLLGGASYNEQFF',
#  'CASRMTGVNEQFF',
#  'CASSPPSQETQYF',
#  'CASSPKSYSNQPQHF',
#  'CASSPGQAEAFF',
#  'CASYGRSGTDTQYF',
#  'CASSLAGMIKETQYF',
#  'CASSPLTGTQETQYF',
#  'CASSWGSLGEQFF',
#  'CASSPRTSGRSSYEQYF',
#  'CASSLDLVAEQYF',
#  'CASSLEASNQPQHF',
#  'CASSLSGGGLNTEAFF',
#  'CASSFVAGNGEQFF',
#  'CASSLEDNSNQPQHF',
#  'CASSLGHLETQYF',
#  'CASGLVPGGAEAFF',
#  'CASGLQYNEQFF',
#  'CASSPPPGLTYNEQFF',
#  'CASRLAGTDTQYF',
#  'CASSPEGRGADTQYF',
#  'CASSLGLDSYNEQFF',
#  'CASSRTTGTGLNEQFF',
#  'CASSLVLAGGREQYF',
#  'CASSVTGGAYNEQFF',
#  'CASSLGQNYGYTF',
#  'CASSSTGVGTDTQYF',
#  'CASSLGGGRTYNEQFF',
#  'CASSSLAGNNEQFF',
#  'CASSWGTGSDEQYF',
#  'CASRGILQETQYF',
#  'CASSGIRGYEQYF',
#  'CASSSSGLTGELFF',
#  'CASSFTSGRAGELFF',
#  'CASSRDSHYEQYF',
#  'CASSYDYEQYF',
#  'CASSLTGAQGEKLFF',
#  'CASSFDRGRFTGELFF',
#  'CSARSDGEAFF',
#  'CSARGTEQFF',
#  'CSVSLNTEAFF',
#  'CSAAAEETQYF',
#  'CSAAAYNEQFF',
#  'CSAGDSYEQYF',
#  'CASTRGSEQFF',
#  'CASSGGLLNEQFF',
#  'CASSPGYEQYF',
#  'CASSLQGVNYGYTF',
#  'CASSLVFGELFF',
#  'CASELAGHTDTQYF',
#  'CASSPPGPGNTIYF',
#  'CASSEGQGAFYEQYF',
#  'CASSFGRNTEAFF',
#  'CASSLKASYEQFF',
#  'CASSFDGYEQYF',
#  'CASRESYNEQFF',
#  'CASLAGYEQYF',
#  'CASSLRDGFYEQYF',
#  'CASSLITGSYNEQFF',
#  'CASSQFYEQYF',
#  'CASSLQGVGYTF',
#  'CASSLAFNEKLFF',
#  'CASSLGGLAGNTDTQYF',
#  'CASSLDQETQYF',
#  'CASTEHNEQFF',
#  'CASSQTGAYNEQFF',
#  'CASSPVGDETQYF',
#  'CASSRSGTGMETQYF',
#  'CASSPRQSKYSYEQYF',
#  'CASSLQGTEQYF',
#  'CASSPGTGTQYF',
#  'CASGAQGNTGELFF',
#  'CASGSGAGVTGELFF',
#  'CSAVRDTQYF',
#  'CSASSQETQYF',
#  'CSARDGEEFF',
#  'CSARVTTEQYF',
#  'CASSLGGNTEAFF',
#  'CASSSGGADTQYF',
#  'CASRSGWDTEAFF',
#  'CASSDRQNQPQHF',
#  'CASSGRERGGGTQYF',
#  'CASSGDSQGYTF',
#  'CASSEVAANTGELFF',
#  'CASSLQGDGNQPQHF',
#  'CASSLVTGVNTEAFF',
#  'CASSSGVEQYF',
#  'CASSLGEGSTYEQYF',
#  'CASSIGRTSSYEQYF',
#  'CASSMAGVFGYTF',
#  'CASSLGQGKDQPQHF',
#  'CASSDGVNEKLFF',
#  'CASSSRYTGELFF',
#  'CASSFRETQYF',
#  'CASSGDSSYEQYF',
#  'CASSPDRAFYEQYF',
#  'CASSFSSSYNEQFF',
#  'CASSQDTGELFF',
#  'CASSLVSYQETQYF',
#  'CASSLDRAEAFF',
#  'CASIFSNEQFF',
#  'CASSLLGGSSYEQYF',
#  'CASSDSTEAFF',
#  'CASSLPGANEQFF',
#  'CASSILQGNYGYTF',
#  'CASSFARGGNYGYTF',
#  'CASSLLGSNQPQHF',
#  'CASSLQGWNTEAFF',
#  'CASILGQGGQPQHF',
#  'CASSSGSASETQYF',
#  'CASSLQGVVSYEQYF',
#  'CASSGTQETQYF',
#  'CASSLGRDPTYEQYF',
#  'CASSPRQGDTGELFF',
#  'CASSLAGGSEQYF',
#  'CASSLDRNSNQPQHF',
#  'CASSPPLVDYGYTF',
#  'CASSPRTGYAEQYF',
#  'CASSLGGKGENTEAFF',
#  'CASVDSTGELFF',
#  'CASGQPSGANVLTF',
#  'CSATPSNEQFF',
#  'CSANRGNEQFF',
#  'CSAQTSGEQYF',
#  'CSASIYGYTF',
#  'CSARDQREQYF',
#  'CSARAIGEQYF',
#  'CSARPGDEQFF',
#  'CSARKEDTQYF',
#  'CSAAGYEQYF',
#  'CASSEDRGRNEKLFF',
#  'CASSPRDRNEKLFF',
#  'CASSFGPSYEQYF',
#  'CASSLAGTSGSSYNEQFF',
#  'CASSLGTASSYNEQFF',
#  'CASSLDRGSSYEQYF',
#  'CASSLDRTSGNTIYF',
#  'CASSPRAATGELFF',
#  'CASSLSGGRETQYF',
#  'CASSRKPNYEQYF',
#  'CASSIGVANTGELFF',
#  'CASSDTGDEQYF',
#  'CASSSEGAGYGYTF',
#  'CASSPTGAYEQYF',
#  'CASSLSAGSYEQYF',
#  'CASSFETGSQHF',
#  'CASSYGTLHTDTQYF',
#  'CASSLSGGYQETQYF',
#  'CASSLAPGRTDTQYF',
#  'CASSRTGNNEQFF',
#  'CASSFSGSNEQFF',
#  'CASSPGTGTIDTQYF',
#  'CASSLAGTRTGELFF',
#  'CASRITGFYEQYF',
#  'CASSSTSGRAHYEQYF',
#  'CASSLSGSGLPYEQYF',
#  'CASSVGEKLFF',
#  'CASSLDISPYEQYF',
#  'CASSPGTGVYGYTF',
#  'CASSLGGAQNTEAFF',
#  'CASGLGQQETQYF',
#  'CASSLSGGGYQPQHF',
#  'CASSLEVLAGANEQFF',
#  'CASSLGTSSGANVLTF',
#  'CASSPRQGAYEQYF',
#  'CASSLGSSYEQYF',
#  'CASSTRGNQPQHF',
#  'CASSPAGLDTEAFF',
#  'CASSRTSGSLYEQFF',
#  'CASSPPVTDTQYF',
#  'CASSPLGNGYEQYF',
#  'CASSPLQGASQPQHF',
#  'CASSPNPSGNTIYF',
#  'CASSPGENPYEQYF',
#  'CASSSAPGNEQFF',
#  'CASSQGQADTQYF',
#  'CASSMGLAVYNEQFF',
#  'CASSPTTGSGANVLTF',
#  'CASSIGGSGQPQHF',
#  'CASSMAGGLSGTGELFF',
#  'CASSIRDSQETQYF',
#  'CASTGLAGGNEQFF',
#  'CASKGTVGYEQYF',
#  'CASSPRQGGETQYF',
#  'CASVSGELFF',
#  'CASSLDQRQETQYF',
#  'CASRTGPAETQYF',
#  'CASSLGGRHNEQFF',
#  'CASSTDRNEQFF',
#  'CASSPTSGSTTEAFF',
#  'CASSSLAGFTDTQYF',
#  'CASRGRSGANVLTF',
#  'CASSEIGETQYF',
#  'CASSGTSGSGTYNEQFF',
#  'CASRDYNEQFF',
#  'CASKVDRGEQYF',
#  'CASSFSPSYNEQFF',
#  'CASSVAGAGGNEQFF',
#  'CASSFIQSSYNEQFF',
#  'CASSLGGYDETQYF',
#  'CASSLEGTGDYGYTF',
#  'CASSLAGGDIQYF',
#  'CASSQGSYNQPQHF',
#  'CASSLEGVGYEQYF',
#  'CASSFSYEQYF',
#  'CASSLLIQPQHF',
#  'CASSLLGAGATNEKLFF',
#  'CASSFASGSSYNEQFF',
#  'CASGLGLVEQYF',
#  'CASTSGRPYEQYF',
#  'CASSLRLAREQYF',
#  'CASSLVGYNEQFF',
#  'CASSQDRGNEQYF',
#  'CASSLRPGSSYEQYF',
#  'CASSLADEKLFF',
#  'CSAGDKYEQYF',
#  'CSAPRGHEQYF',
#  'CSASKADTQYF',
#  'CSAKVVAGYTF',
#  'CASSFSRERGTDTQYF',
#  'CASSLKAGELFF',
#  'CASSLGDEQFF',
#  'CASSLDGFGANVLTF',
#  'CASSLSGYNEQFF',
#  'CASSITGTGELFF',
#  'CASSLATSGQETQYF',
#  'CASSTQGNQPQHF',
#  'CASRLAGDTGELFF',
#  'CASIQRGTDTQYF',
#  'CASSIGLVDEQFF',
#  'CASRMTGTYEQYF',
#  'CASSMGGGAYEQYF',
#  'CASSIQGAYGYTF',
#  'CASRNRGGSYNEQFF',
#  'CASRGQGSRQPQHF',
#  'CASRVAGASTDTQYF',
#  'CASRLAGASDTQYF',
#  'CASGSTGASTDTQYF',
#  'CASGQGNEQFF',
#  'CASSPSAGRETQYF',
#  'CASSPRLATGELFF',
#  'CASSPRGTDTQYF',
#  'CASSLPRQGGSYNEQFF',
#  'CASSPTSGSRIEQFF',
#  'CASSPDSYEQYF',
#  'CASSQGQGPYEQYF',
#  'CASSLGQDEKLFF',
#  'CASSLGTGISGETQYF',
#  'CASSFGPNYEQYF',
#  'CASSFLAGGPGELFF',
#  'CASSFPSYEQYF',
#  'CASSLKGQGHEKLFF',
#  'CASSRDGHTEAFF',
#  'CASSLGPISNQPQHF',
#  ...]

# %%
q = [tn for tn in example if foreground[tn] > res[tn]]
# Out:
# 157747
# 53061

# %%
nbr_counts = {i:(foreground[i], background[i])  for i in foreground}

# %%
nbr_counts['CASRSGANQETQYF']
# Out:
# (2, 0)

# %%
from scipy.stats import hypergeom

# def hypergeom_test(fg_n, bg_n, fg_total, bg_total):

fg_total = len(example)
bg_total = len(control)

for seq in example[:100]:
    fg_n = foreground[seq]
    bg_n = background[seq]
    if fg_n > 1:
        pval = hypergeom.sf(fg_n, fg_total+bg_total, fg_total, fg_n+bg_n)
        print(seq, pval)

# res
# Out:
# CASSLSGAGNTIYF 4.66335379607846e-07
# CASSLLAGPYNEQFF 5.4140047173815666e-06
# CASSTTGGYEQYF 0.11150730829909787
# CASSLGGGTDTQYF 0.0036341176294506484
# CASSLGLAGNEQFF 3.222468974411042e-06
# CASSLGAGGETQYF 1.9338935607747338e-06
# CASSYVGGGNQPQHF 0.01336759016161031
# CASSRDRNYGYTF 0.39266872047719764
# CASSRTGGTNTEAFF 0.14724198749116527
# CASSRAGFYGYTF 0.2963029692859804
# CASSFGGAEQFF 0.00114039773808137
# CASSLEGIGNQPQHF 7.749627299947894e-05
# CASSLTAEQFF 0.0007128859970093752
# CASSLSAEQFF 2.4415003295622482e-05
# CASSRDRVSYEQYF 0.011067055814494969
# CASSFGGSSYEQYF 0.00025379417053613535
# CASSSRRGSTDTQYF 0.10721036670438983
# CASSLAGTLEKLFF 0.04525259014970305
# CASSTLGSTNEKLFF 0.013794323911244171
# CASSFPGTEAFF 0.00759474942359124
# CASSLGGGNTIYF 0.0005705339232546909
# CASSLGSGSYEQYF 5.731768615934041e-06
# CASSLVAGGSNTGELFF 0.010686179010388364
# CASSLLADTSTDTQYF 0.013794323911244171
# CASRSGANQETQYF 0.0
# CASSLGGISDTQYF 2.1199044000546524e-05
# CASSGGQGSNQPQHF 0.49292161850116745
# CASSLAQGRNYGYTF 0.5128937500931292
# CASSLGGANTQYF 0.22276981811550559
# CASSAPQGAYEQYF 0.22276981811550559
# CASSLRENTEAFF 5.6770404495897125e-05
# CASSLEGRGETQYF 0.00019165841660256607
# CASSLAGTGVYEQYF 6.968321882234637e-05
# CASSLGGGYGYTF 0.02897372478276475
# CASSLQGSPNYGYTF 0.0
# CASSPTGTDTQYF 0.011832587439960884
# CASSLRPGQTYEQYF 0.0033082351662001067
